# %% [markdown]
# Introduction
# AlexNet was designed by Hinton, winner of the 2012 ImageNet competition, and his student Alex Krizhevsky. It was also after that year that more and deeper neural networks were proposed, such as the excellent vgg, GoogleLeNet. Its official data model has an accuracy rate of 57.1% and top 1-5 reaches 80.2%. This is already quite outstanding for traditional machine learning classification algorithms.
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <table>
# <thead>
#     <tr>
#         <th>Size / Operation</th>
#         <th>Filter</th>
#         <th>Depth</th>
#         <th>Stride</th>
#         <th>Padding</th>
#         <th>Number of Parameters</th>
#         <th>Forward Computation</th>
#     </tr>
# </thead>
# <tbody>
#     <tr>
#         <td>3* 227 * 227</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>Conv1 + Relu</td>
#         <td>11 * 11</td>
#         <td>96</td>
#         <td>4</td>
#         <td></td>
#         <td>(11*11*3 + 1) * 96=34944</td>
#         <td>(11*11*3 + 1) * 96 * 55 * 55=105705600</td>
#     </tr>
#     <tr>
#         <td>96 * 55 * 55</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>Max Pooling</td>
#         <td>3 * 3</td>
#         <td></td>
#         <td>2</td>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>96 * 27 * 27</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>Norm</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>Conv2 + Relu</td>
#         <td>5 * 5</td>
#         <td>256</td>
#         <td>1</td>
#         <td>2</td>
#         <td>(5 * 5 * 96 + 1) * 256=614656</td>
#         <td>(5 * 5 * 96 + 1) * 256 * 27 * 27=448084224</td>
#     </tr>
#     <tr>
#         <td>256 * 27 * 27</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>Max Pooling</td>
#         <td>3 * 3</td>
#         <td></td>
#         <td>2</td>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>256 * 13 * 13</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>Norm</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>Conv3 + Relu</td>
#         <td>3 * 3</td>
#         <td>384</td>
#         <td>1</td>
#         <td>1</td>
#         <td>(3 * 3 * 256 + 1) * 384=885120</td>
#         <td>(3 * 3 * 256 + 1) * 384 * 13 * 13=149585280</td>
#     </tr>
#     <tr>
#         <td>384 * 13 * 13</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>Conv4 + Relu</td>
#         <td>3 * 3</td>
#         <td>384</td>
#         <td>1</td>
#         <td>1</td>
#         <td>(3 * 3 * 384 + 1) * 384=1327488</td>
#         <td>(3 * 3 * 384 + 1) * 384 * 13 * 13=224345472</td>
#     </tr>
#     <tr>
#         <td>384 * 13 * 13</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>Conv5 + Relu</td>
#         <td>3 * 3</td>
#         <td>256</td>
#         <td>1</td>
#         <td>1</td>
#         <td>(3 * 3 * 384 + 1) * 256=884992</td>
#         <td>(3 * 3 * 384 + 1) * 256 * 13 * 13=149563648</td>
#     </tr>
#     <tr>
#         <td>256 * 13 * 13</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>Max Pooling</td>
#         <td>3 * 3</td>
#         <td></td>
#         <td>2</td>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>256 * 6 * 6</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>Dropout (rate 0.5)</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>FC6 + Relu</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td>256 * 6 * 6 * 4096=37748736</td>
#         <td>256 * 6 * 6 * 4096=37748736</td>
#     </tr>
#     <tr>
#         <td>4096</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>Dropout (rate 0.5)</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>FC7 + Relu</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td>4096 * 4096=16777216</td>
#         <td>4096 * 4096=16777216</td>
#     </tr>
#     <tr>
#         <td>4096</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>FC8 + Relu</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td>4096 * 1000=4096000</td>
#         <td>4096 * 1000=4096000</td>
#     </tr>
#     <tr>
#         <td>1000 classes</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#     </tr>
#     <tr>
#         <td>Overall</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td>62369152=62.3 million</td>
#         <td>1135906176=1.1 billion</td>
#     </tr>
#     <tr>
#         <td>Conv VS FC</td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td>Conv:3.7million (6%) , FC: 58.6 million  (94% )</td>
#         <td>Conv: 1.08 billion (95%) , FC: 58.6 million (5%)</td>
#     </tr>
# </tbody>
# </table>

# %% [markdown]
# Why does AlexNet achieve better results?¶
# Relu activation function is used:
# Relu function: f (x) = max (0, x)
#
# ![image.png](attachment:image.png)
#
# ReLU-based deep convolutional networks are trained several times faster than tanh and sigmoid- based networks. The following figure shows the number of iterations for a four-layer convolutional network based on CIFAR-10 that reached 25% training error in tanh and ReLU:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Standardization (Local Response Normalization):
# After using ReLU f (x) = max (0, x), you will find that the value after the activation function has no range like the tanh and sigmoid functions, so a normalization will usually be done after ReLU, and the LRU is a steady proposal (Not sure here, it should be proposed?) One method in neuroscience is called "Lateral inhibition", which talks about the effect of active neurons on its surrounding neurons.
#
# ![image.png](attachment:image.png)
#
# Dropout:
# Dropout is also a concept often said, which can effectively prevent overfitting of neural networks. Compared to the general linear model, a regular method is used to prevent the model from overfitting. In the neural network, Dropout is implemented by modifying the structure of the neural network itself. For a certain layer of neurons, randomly delete some neurons with a defined probability, while keeping the individuals of the input layer and output layer neurons unchanged, and then update the parameters according to the learning method of the neural network. In the next iteration, rerandom Remove some neurons until the end of training.
#
# ![image-2.png](attachment:image-2.png)
#
# Enhanced Data (Data Augmentation):
# In deep learning, when the amount of data is not large enough, there are generally 4 solutions:
#
# Data augmentation- artificially increase the size of the training set-create a batch of "new" data from existing data by means of translation, flipping, noise
#
# Regularization——The relatively small amount of data will cause the model to overfit, making the training error small and the test error particularly large. By adding a regular term after the Loss Function , the overfitting can be suppressed. The disadvantage is that a need is introduced Manually adjusted hyper-parameter.
#
# Dropout- also a regularization method. But different from the above, it is achieved by randomly setting the output of some neurons to zero
#
# Unsupervised Pre-training- use Auto-Encoder or RBM's convolution form to do unsupervised pre-training layer by layer, and finally add a classification layer to do supervised Fine-Tuning

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader,Dataset
from torchvision import transforms as T

# %%
class alexnet(nn.Module):
    def __init__(self,):
        """
        The expression super(alexnet, self).__init__() in Python is used within a class that inherits from another class to call the __init__ method of the parent class. This ensures that the parent class is properly initialized, allowing the child class to build upon it.
        
        formula for finding outshape of conv is [(W−K+2P)/S]+1
        W is width
        K is kernel size
        P is padding
        S is stride
        
        
        """
        
        super(alexnet,self).__init__()
        # conv
        self.conv1 = nn.Conv2d(3,96,[11,11],4)
        self.conv2 = nn.Conv2d(96,256,[5,5],1,2)
        self.conv3 = nn.Conv2d(256,384,[3,3],1,1)
        self.conv4 = nn.Conv2d(384,384,[3,3],1,1)
        self.conv5 = nn.Conv2d(384,256,[3,3],1,1)

        # pooling 
        self.pool = nn.MaxPool2d(3,2)
        
        # activation
        self.relu = nn.ReLU()
        
        #fully connected
        self.fc1 = nn.Linear(256*6*6,4096)
        self.fc2 = nn.Linear(4096,1000)
        
        
        
        
    def forward(self,x):
        x = self.conv1(x)
        
        # w = 227
        # k = 11
        # p = 0
        # s = 4
        # ( (w - k +2*p)/s ) + 1 == 55
        x = self.relu(x)
        x = self.pool(x)
        
        # w = 55
        # k = 3
        # p = 0
        # s = 2
        # ( (w - k +2*p)/s ) + 1  == 27
        x = self.conv2(x)
        
        # w = 27
        # k = 5
        # p = 2
        # s = 1
        # ( (w - k +(2*p) ) /s ) + 1 ==27
        x = self.relu(x)
        x = self.pool(x)
        # w = 27
        # k = 3
        # p = 0
        # s = 2
        # ( (w - k +(2*p) ) /s ) + 1 == 13
        x = self.conv3(x)
        # w = 13
        # k = 3
        # p = 1
        # s = 1
        # ( (w - k +(2*p) ) /s ) + 1 == 13
        x = self.relu(x)
        x = self.conv4(x)
        # w = 13
        # k = 3
        # p = 1
        # s = 1
        # ( (w - k +(2*p) ) /s ) + 1 == 13
        x = self.relu(x)
        x = self.conv5(x)
        # w = 13
        # k = 3
        # p = 1
        # s = 1
        # ( (w - k +(2*p) ) /s ) + 1 == 13              
        
        x = self.relu(x)
        x = self.pool(x)
        # w = 13
        # k = 3
        # p = 0
        # s = 2
        # ( (w - k +(2*p) ) /s ) + 1 == 6
                
        x = x.view(x.size(0),-1)
        
        
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.relu(x)
        return x

    
    
        
        
model = alexnet()
model
# Out:
# alexnet(
#   (conv1): Conv2d(3, 96, kernel_size=(11, 11), stride=(4, 4))
#   (conv2): Conv2d(96, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv3): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (relu): ReLU()
#   (fc1): Linear(in_features=9216, out_features=4096, bias=True)
#   (fc2): Linear(in_features=4096, out_features=1000, bias=True)
# )

# %%
transformer = T.Compose([
    T.ToTensor(),
    T.Resize([227,227]),
    T.Lambda(lambda x: x[0].repeat(3,1,1))
])

# %%
dataset_train=MNIST("./data",train=True,download=True,transform=transformer)
dataset_train
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: ./data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Resize(size=[227, 227], interpolation=bilinear, max_size=None, antialias=None)
#                Lambda()
#            )

# %%
dataset_test=MNIST("./data",train=False,download=True,transform=transformer)
dataset_test
# Out:
# Dataset MNIST
#     Number of datapoints: 10000
#     Root location: ./data
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Resize(size=[227, 227], interpolation=bilinear, max_size=None, antialias=None)
#                Lambda()
#            )

# %%
train_dataloader = DataLoader(dataset_train,4,True)
test_dataloader = DataLoader(dataset_test,4,True)

# %%
"""
When training a model, it's more efficient and 
numerically stable to use nn.CrossEntropyLoss 
directly rather than applying softmax followed by a loss function. 
This is because nn.CrossEntropyLoss performs both the softmax and 
the log operations in a single step, which helps avoid potential 
numerical instability issues that can arise when dealing with very 
small or very large values.

"""

criterion = nn.CrossEntropyLoss()

# %%
        
model = alexnet()
model
# Out:
# alexnet(
#   (conv1): Conv2d(3, 96, kernel_size=(11, 11), stride=(4, 4))
#   (conv2): Conv2d(96, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv3): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (relu): ReLU()
#   (fc1): Linear(in_features=9216, out_features=4096, bias=True)
#   (fc2): Linear(in_features=4096, out_features=1000, bias=True)
# )

# %%
optmizer = optim.Adam(model.parameters(),lr=0.00001)

# %%
model.train()

num_epochs =10
for epoch in range(num_epochs):
    for xtrain,ytrain in train_dataloader:
        optmizer.zero_grad()
        
        output = model(xtrain)
        loss = criterion(output,ytrain)
        loss.backward()
        optmizer.step()
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/10], Loss: 6.9066
# Epoch [1/10], Loss: 6.9045
# Epoch [1/10], Loss: 6.8990
# Epoch [1/10], Loss: 6.9009
# Epoch [1/10], Loss: 6.9054
# Epoch [1/10], Loss: 6.9116
# Epoch [1/10], Loss: 6.8839
# Epoch [1/10], Loss: 6.8722
# Epoch [1/10], Loss: 6.8671
# Epoch [1/10], Loss: 6.8957
# Epoch [1/10], Loss: 6.8968
# Epoch [1/10], Loss: 6.9112
# Epoch [1/10], Loss: 6.9065
# Epoch [1/10], Loss: 6.9101
# Epoch [1/10], Loss: 6.8742
# Epoch [1/10], Loss: 6.8466
# Epoch [1/10], Loss: 6.8492
# Epoch [1/10], Loss: 6.9050
# Epoch [1/10], Loss: 6.8688
# Epoch [1/10], Loss: 6.8346
# Epoch [1/10], Loss: 6.8912
# Epoch [1/10], Loss: 6.8000
# Epoch [1/10], Loss: 6.7399
# Epoch [1/10], Loss: 6.8176
# Epoch [1/10], Loss: 6.7112
# Epoch [1/10], Loss: 6.7654
# Epoch [1/10], Loss: 6.7655
# Epoch [1/10], Loss: 6.6343
# Epoch [1/10], Loss: 6.6885
# Epoch [1/10], Loss: 6.6820
# Epoch [1/10], Loss: 6.6577
# Epoch [1/10], Loss: 6.7320
# Epoch [1/10], Loss: 6.5283
# Epoch [1/10], Loss: 6.3726
# Epoch [1/10], Loss: 6.2969
# Epoch [1/10], Loss: 6.3963
# Epoch [1/10], Loss: 6.2547
# Epoch [1/10], Loss: 5.9701
# Epoch [1/10], Loss: 6.4093
# Epoch [1/10], Loss: 6.2926
# Epoch [1/10], Loss: 5.8323
# Epoch [1/10], Loss: 5.7321
# Epoch [1/10], Loss: 5.8523
# Epoch [1/10], Loss: 4.9168
# Epoch [1/10], Loss: 5.2925
# Epoch [1/10], Loss: 4.6135
# Epoch [1/10], Loss: 5.1276
# Epoch [1/10], Loss: 4.9819
# Epoch [1/10], Loss: 4.6966
# Epoch [1/10], Loss: 4.0586
# Epoch [1/10], Loss: 3.7232
# Epoch [1/10], Loss: 4.7137
# Epoch [1/10], Loss: 3.5040
# Epoch [1/10], Loss: 4.2582
# Epoch [1/10], Loss: 3.2626
# Epoch [1/10], Loss: 3.5785
# Epoch [1/10], Loss: 4.0733
# Epoch [1/10], Loss: 3.3305
# Epoch [1/10], Loss: 2.0907
# Epoch [1/10], Loss: 2.4777
# Epoch [1/10], Loss: 2.4604
# Epoch [1/10], Loss: 2.1483
# Epoch [1/10], Loss: 2.7262
# Epoch [1/10], Loss: 2.6495
# Epoch [1/10], Loss: 2.0945
# Epoch [1/10], Loss: 2.4857
# Epoch [1/10], Loss: 2.4317
# Epoch [1/10], Loss: 2.6354
# Epoch [1/10], Loss: 2.4052
# Epoch [1/10], Loss: 2.1176
# Epoch [1/10], Loss: 2.8865
# Epoch [1/10], Loss: 2.1716
# Epoch [1/10], Loss: 3.2458
# Epoch [1/10], Loss: 1.8808
# Epoch [1/10], Loss: 1.9388
# Epoch [1/10], Loss: 2.5457
# Epoch [1/10], Loss: 2.4975
# Epoch [1/10], Loss: 2.6065
# Epoch [1/10], Loss: 2.1214
# Epoch [1/10], Loss: 2.6354
# Epoch [1/10], Loss: 2.1351
# Epoch [1/10], Loss: 2.1669
# Epoch [1/10], Loss: 2.1899
# Epoch [1/10], Loss: 2.2871
# Epoch [1/10], Loss: 1.9847
# Epoch [1/10], Loss: 2.0132
# Epoch [1/10], Loss: 2.2735
# Epoch [1/10], Loss: 2.1572
# Epoch [1/10], Loss: 2.0676
# Epoch [1/10], Loss: 2.3718
# Epoch [1/10], Loss: 2.6376
# Epoch [1/10], Loss: 2.4050
# Epoch [1/10], Loss: 2.5082
# Epoch [1/10], Loss: 2.2801
# Epoch [1/10], Loss: 1.7637
# Epoch [1/10], Loss: 1.8343
# Epoch [1/10], Loss: 2.3284
# Epoch [1/10], Loss: 2.6848
# Epoch [1/10], Loss: 2.0896
# Epoch [1/10], Loss: 2.1869
# Epoch [1/10], Loss: 2.1258
# Epoch [1/10], Loss: 1.9588
# Epoch [1/10], Loss: 2.5771
# Epoch [1/10], Loss: 2.3310
# Epoch [1/10], Loss: 1.7196
# Epoch [1/10], Loss: 1.6080
# Epoch [1/10], Loss: 1.9625
# Epoch [1/10], Loss: 1.7243
# Epoch [1/10], Loss: 2.0298
# Epoch [1/10], Loss: 1.8598
# Epoch [1/10], Loss: 2.1939
# Epoch [1/10], Loss: 2.7998
# Epoch [1/10], Loss: 1.7097
# Epoch [1/10], Loss: 2.6273
# Epoch [1/10], Loss: 2.7381
# Epoch [1/10], Loss: 1.9718
# Epoch [1/10], Loss: 2.0935
# Epoch [1/10], Loss: 1.8297
# Epoch [1/10], Loss: 1.6119
# Epoch [1/10], Loss: 2.0047
# Epoch [1/10], Loss: 2.3925
# Epoch [1/10], Loss: 2.3117
# Epoch [1/10], Loss: 1.8685
# Epoch [1/10], Loss: 1.8007
# Epoch [1/10], Loss: 2.0832
# Epoch [1/10], Loss: 2.3576
# Epoch [1/10], Loss: 1.9876
# Epoch [1/10], Loss: 2.0515
# Epoch [1/10], Loss: 2.0786
# Epoch [1/10], Loss: 2.0458
# Epoch [1/10], Loss: 2.5048
# Epoch [1/10], Loss: 1.6945
# Epoch [1/10], Loss: 1.8163
# Epoch [1/10], Loss: 1.4571
# Epoch [1/10], Loss: 1.9922
# Epoch [1/10], Loss: 1.6192
# Epoch [1/10], Loss: 2.6483
# Epoch [1/10], Loss: 1.8057
# Epoch [1/10], Loss: 1.9940
# Epoch [1/10], Loss: 1.7190
# Epoch [1/10], Loss: 1.5328
# Epoch [1/10], Loss: 1.4433
# Epoch [1/10], Loss: 1.9368
# Epoch [1/10], Loss: 2.4368
# Epoch [1/10], Loss: 2.1195
# Epoch [1/10], Loss: 2.2346
# Epoch [1/10], Loss: 1.2900
# Epoch [1/10], Loss: 2.5416
# Epoch [1/10], Loss: 2.8231
# Epoch [1/10], Loss: 2.0800
# Epoch [1/10], Loss: 1.3913
# Epoch [1/10], Loss: 2.1971
# Epoch [1/10], Loss: 1.8232
# Epoch [1/10], Loss: 1.2244
# Epoch [1/10], Loss: 1.5883
# Epoch [1/10], Loss: 1.7688
# Epoch [1/10], Loss: 1.6743
# Epoch [1/10], Loss: 1.8335
# Epoch [1/10], Loss: 1.8967
# Epoch [1/10], Loss: 1.7557
# Epoch [1/10], Loss: 2.5585
# Epoch [1/10], Loss: 1.7122
# Epoch [1/10], Loss: 2.1344
# Epoch [1/10], Loss: 1.5021
# Epoch [1/10], Loss: 1.7778
# Epoch [1/10], Loss: 1.5923
# Epoch [1/10], Loss: 1.6250
# Epoch [1/10], Loss: 1.6527
# Epoch [1/10], Loss: 1.8972
# Epoch [1/10], Loss: 2.2409
# Epoch [1/10], Loss: 1.3380
# Epoch [1/10], Loss: 1.7352
# Epoch [1/10], Loss: 2.0732
# Epoch [1/10], Loss: 1.2471
# Epoch [1/10], Loss: 1.3625
# Epoch [1/10], Loss: 1.0619
# Epoch [1/10], Loss: 1.2559
# Epoch [1/10], Loss: 2.1122
# Epoch [1/10], Loss: 1.7351
# Epoch [1/10], Loss: 1.9164
# Epoch [1/10], Loss: 2.0559
# Epoch [1/10], Loss: 1.4274
# Epoch [1/10], Loss: 2.5568
# Epoch [1/10], Loss: 1.3564
# Epoch [1/10], Loss: 1.4926
# Epoch [1/10], Loss: 1.4983
# Epoch [1/10], Loss: 1.5099
# Epoch [1/10], Loss: 2.2133
# Epoch [1/10], Loss: 2.5079
# Epoch [1/10], Loss: 1.4094
# Epoch [1/10], Loss: 2.6095
# Epoch [1/10], Loss: 1.8399
# Epoch [1/10], Loss: 1.5558
# Epoch [1/10], Loss: 1.5168
# Epoch [1/10], Loss: 1.6369
# Epoch [1/10], Loss: 1.0450
# Epoch [1/10], Loss: 1.7538
# Epoch [1/10], Loss: 2.2600
# Epoch [1/10], Loss: 1.2464
# Epoch [1/10], Loss: 1.2824
# Epoch [1/10], Loss: 1.7536
# Epoch [1/10], Loss: 0.8750
# Epoch [1/10], Loss: 1.4728
# Epoch [1/10], Loss: 1.9116
# Epoch [1/10], Loss: 0.8658
# Epoch [1/10], Loss: 1.7205
# Epoch [1/10], Loss: 1.7192
# Epoch [1/10], Loss: 2.1986
# Epoch [1/10], Loss: 1.2961
# Epoch [1/10], Loss: 1.3937
# Epoch [1/10], Loss: 1.5507
# Epoch [1/10], Loss: 1.2702
# Epoch [1/10], Loss: 2.0866
# Epoch [1/10], Loss: 2.1170
# Epoch [1/10], Loss: 1.2515
# Epoch [1/10], Loss: 2.4644
# Epoch [1/10], Loss: 0.9820
# Epoch [1/10], Loss: 1.3195
# Epoch [1/10], Loss: 0.5472
# Epoch [1/10], Loss: 1.5845
# Epoch [1/10], Loss: 1.8347
# Epoch [1/10], Loss: 2.0407
# Epoch [1/10], Loss: 1.7928
# Epoch [1/10], Loss: 1.1300
# Epoch [1/10], Loss: 1.5880
# Epoch [1/10], Loss: 0.6685
# Epoch [1/10], Loss: 0.7091
# Epoch [1/10], Loss: 1.2441
# Epoch [1/10], Loss: 0.7960
# Epoch [1/10], Loss: 1.7416
# Epoch [1/10], Loss: 1.9763
# Epoch [1/10], Loss: 2.0226
# Epoch [1/10], Loss: 1.8079
# Epoch [1/10], Loss: 1.5210
# Epoch [1/10], Loss: 0.9411
# Epoch [1/10], Loss: 1.9604
# Epoch [1/10], Loss: 1.2233
# Epoch [1/10], Loss: 1.2696
# Epoch [1/10], Loss: 2.1717
# Epoch [1/10], Loss: 0.9092
# Epoch [1/10], Loss: 2.0318
# Epoch [1/10], Loss: 1.8803
# Epoch [1/10], Loss: 1.5199
# Epoch [1/10], Loss: 1.3656
# Epoch [1/10], Loss: 0.8651
# Epoch [1/10], Loss: 2.1166
# Epoch [1/10], Loss: 1.8261
# Epoch [1/10], Loss: 1.0365
# Epoch [1/10], Loss: 1.6366
# Epoch [1/10], Loss: 0.9027
# Epoch [1/10], Loss: 1.5167
# Epoch [1/10], Loss: 1.3248
# Epoch [1/10], Loss: 1.4938
# Epoch [1/10], Loss: 0.9915
# Epoch [1/10], Loss: 1.5598
# Epoch [1/10], Loss: 1.3200
# Epoch [1/10], Loss: 1.2738
# Epoch [1/10], Loss: 1.0456
# Epoch [1/10], Loss: 0.5182
# Epoch [1/10], Loss: 0.8931
# Epoch [1/10], Loss: 1.1721
# Epoch [1/10], Loss: 0.8252
# Epoch [1/10], Loss: 0.6196
# Epoch [1/10], Loss: 2.1532
# Epoch [1/10], Loss: 1.6770
# Epoch [1/10], Loss: 1.0434
# Epoch [1/10], Loss: 0.9660
# Epoch [1/10], Loss: 1.1403
# Epoch [1/10], Loss: 1.3496
# Epoch [1/10], Loss: 0.3267
# Epoch [1/10], Loss: 1.8517
# Epoch [1/10], Loss: 1.0102
# Epoch [1/10], Loss: 1.0273
# Epoch [1/10], Loss: 0.7512
# Epoch [1/10], Loss: 0.8345
# Epoch [1/10], Loss: 1.3425
# Epoch [1/10], Loss: 0.7662
# Epoch [1/10], Loss: 1.1161
# Epoch [1/10], Loss: 1.9542
# Epoch [1/10], Loss: 1.8082
# Epoch [1/10], Loss: 1.3211
# Epoch [1/10], Loss: 0.5676
# Epoch [1/10], Loss: 1.2946
# Epoch [1/10], Loss: 1.2255
# Epoch [1/10], Loss: 1.2596
# Epoch [1/10], Loss: 1.0098
# Epoch [1/10], Loss: 0.8440
# Epoch [1/10], Loss: 0.7897
# Epoch [1/10], Loss: 0.8597
# Epoch [1/10], Loss: 1.4760
# Epoch [1/10], Loss: 1.6342
# Epoch [1/10], Loss: 0.9226
# Epoch [1/10], Loss: 1.1139
# Epoch [1/10], Loss: 0.4833
# Epoch [1/10], Loss: 0.2120
# Epoch [1/10], Loss: 0.4924
# Epoch [1/10], Loss: 1.0965
# Epoch [1/10], Loss: 1.8648
# Epoch [1/10], Loss: 0.5375
# Epoch [1/10], Loss: 0.8571
# Epoch [1/10], Loss: 0.3196
# Epoch [1/10], Loss: 0.0954
# Epoch [1/10], Loss: 1.2128
# Epoch [1/10], Loss: 0.4697
# Epoch [1/10], Loss: 0.7849
# Epoch [1/10], Loss: 2.7983
# Epoch [1/10], Loss: 1.2973
# Epoch [1/10], Loss: 0.5137
# Epoch [1/10], Loss: 0.8508
# Epoch [1/10], Loss: 1.8723
# Epoch [1/10], Loss: 0.1980
# Epoch [1/10], Loss: 0.6366
# Epoch [1/10], Loss: 0.4951
# Epoch [1/10], Loss: 1.0037
# Epoch [1/10], Loss: 2.4014
# Epoch [1/10], Loss: 1.0889
# Epoch [1/10], Loss: 0.4831
# Epoch [1/10], Loss: 0.2919
# Epoch [1/10], Loss: 1.4924
# Epoch [1/10], Loss: 1.2198
# Epoch [1/10], Loss: 1.0282
# Epoch [1/10], Loss: 0.9894
# Epoch [1/10], Loss: 0.1564
# Epoch [1/10], Loss: 0.6644
# Epoch [1/10], Loss: 0.5269
# Epoch [1/10], Loss: 1.2004
# Epoch [1/10], Loss: 1.7027
# Epoch [1/10], Loss: 1.3687
# Epoch [1/10], Loss: 0.3700
# Epoch [1/10], Loss: 1.7737
# Epoch [1/10], Loss: 0.5658
# Epoch [1/10], Loss: 1.4896
# Epoch [1/10], Loss: 1.1732
# Epoch [1/10], Loss: 0.7439
# Epoch [1/10], Loss: 0.4555
# Epoch [1/10], Loss: 0.7346
# Epoch [1/10], Loss: 1.5397
# Epoch [1/10], Loss: 0.6655
# Epoch [1/10], Loss: 1.1317
# Epoch [1/10], Loss: 0.9187
# Epoch [1/10], Loss: 0.3294
# Epoch [1/10], Loss: 1.4421
# Epoch [1/10], Loss: 0.3723
# Epoch [1/10], Loss: 0.9624
# Epoch [1/10], Loss: 0.6485
# Epoch [1/10], Loss: 0.8517
# Epoch [1/10], Loss: 0.3111
# Epoch [1/10], Loss: 0.6808
# Epoch [1/10], Loss: 0.6523
# Epoch [1/10], Loss: 0.6505
# Epoch [1/10], Loss: 1.4186
# Epoch [1/10], Loss: 1.2355
# Epoch [1/10], Loss: 0.8725
# Epoch [1/10], Loss: 0.1888
# Epoch [1/10], Loss: 1.1590
# Epoch [1/10], Loss: 0.5888
# Epoch [1/10], Loss: 0.6570
# Epoch [1/10], Loss: 1.7636
# Epoch [1/10], Loss: 2.0844
# Epoch [1/10], Loss: 0.6212
# Epoch [1/10], Loss: 1.1623
# Epoch [1/10], Loss: 0.5937
# Epoch [1/10], Loss: 1.2177
# Epoch [1/10], Loss: 1.9960
# Epoch [1/10], Loss: 0.4628
# Epoch [1/10], Loss: 0.3501
# Epoch [1/10], Loss: 1.2129
# Epoch [1/10], Loss: 0.9314
# Epoch [1/10], Loss: 0.5235
# Epoch [1/10], Loss: 1.9353
# Epoch [1/10], Loss: 2.3142
# Epoch [1/10], Loss: 0.6334
# Epoch [1/10], Loss: 0.5585
# Epoch [1/10], Loss: 0.2379
# Epoch [1/10], Loss: 0.8949
# Epoch [1/10], Loss: 0.7688
# Epoch [1/10], Loss: 0.6220
# Epoch [1/10], Loss: 1.1576
# Epoch [1/10], Loss: 1.4254
# Epoch [1/10], Loss: 0.5675
# Epoch [1/10], Loss: 0.9508
# Epoch [1/10], Loss: 0.5359
# Epoch [1/10], Loss: 0.4517
# Epoch [1/10], Loss: 0.3881
# Epoch [1/10], Loss: 0.0801
# Epoch [1/10], Loss: 1.3399
# Epoch [1/10], Loss: 0.0582
# Epoch [1/10], Loss: 0.3949
# Epoch [1/10], Loss: 0.6459
# Epoch [1/10], Loss: 0.8370
# Epoch [1/10], Loss: 0.3256
# Epoch [1/10], Loss: 1.0455
# Epoch [1/10], Loss: 0.4061
# Epoch [1/10], Loss: 0.9562
# Epoch [1/10], Loss: 0.4203
# Epoch [1/10], Loss: 1.1496
# Epoch [1/10], Loss: 1.4831
# Epoch [1/10], Loss: 2.2157
# Epoch [1/10], Loss: 0.8539
# Epoch [1/10], Loss: 0.8219
# Epoch [1/10], Loss: 0.3731
# Epoch [1/10], Loss: 0.7915
# Epoch [1/10], Loss: 1.0404
# Epoch [1/10], Loss: 1.8568
# Epoch [1/10], Loss: 0.5839
# Epoch [1/10], Loss: 2.1989
# Epoch [1/10], Loss: 0.6006
# Epoch [1/10], Loss: 0.3486
# Epoch [1/10], Loss: 0.7939
# Epoch [1/10], Loss: 1.7497
# Epoch [1/10], Loss: 1.3748
# Epoch [1/10], Loss: 0.1986
# Epoch [1/10], Loss: 0.6484
# Epoch [1/10], Loss: 0.6919
# Epoch [1/10], Loss: 0.3341
# Epoch [1/10], Loss: 0.2559
# Epoch [1/10], Loss: 0.5569
# Epoch [1/10], Loss: 0.4600
# Epoch [1/10], Loss: 0.5057
# Epoch [1/10], Loss: 0.5983
# Epoch [1/10], Loss: 0.6251
# Epoch [1/10], Loss: 1.0310
# Epoch [1/10], Loss: 0.0622
# Epoch [1/10], Loss: 0.2120
# Epoch [1/10], Loss: 0.9729
# Epoch [1/10], Loss: 0.4937
# Epoch [1/10], Loss: 0.2606
# Epoch [1/10], Loss: 0.2381
# Epoch [1/10], Loss: 0.9947
# Epoch [1/10], Loss: 0.9718
# Epoch [1/10], Loss: 0.9151
# Epoch [1/10], Loss: 0.5934
# Epoch [1/10], Loss: 0.6778
# Epoch [1/10], Loss: 1.1399
# Epoch [1/10], Loss: 0.3775
# Epoch [1/10], Loss: 0.7521
# Epoch [1/10], Loss: 0.8068
# Epoch [1/10], Loss: 1.0617
# Epoch [1/10], Loss: 0.3793
# Epoch [1/10], Loss: 0.2963
# Epoch [1/10], Loss: 0.1703
# Epoch [1/10], Loss: 0.4779
# Epoch [1/10], Loss: 0.0292
# Epoch [1/10], Loss: 0.6964
# Epoch [1/10], Loss: 0.0967
# Epoch [1/10], Loss: 0.2232
# Epoch [1/10], Loss: 0.6213
# Epoch [1/10], Loss: 0.3338
# Epoch [1/10], Loss: 0.2734
# Epoch [1/10], Loss: 0.1205
# Epoch [1/10], Loss: 0.3430
# Epoch [1/10], Loss: 0.6912
# Epoch [1/10], Loss: 4.2892
# Epoch [1/10], Loss: 1.4088
# Epoch [1/10], Loss: 0.0553
# Epoch [1/10], Loss: 0.4385
# Epoch [1/10], Loss: 1.0645
# Epoch [1/10], Loss: 0.8053
# Epoch [1/10], Loss: 0.4717
# Epoch [1/10], Loss: 1.4625
# Epoch [1/10], Loss: 0.9664
# Epoch [1/10], Loss: 0.2718
# Epoch [1/10], Loss: 0.2329
# Epoch [1/10], Loss: 0.9490
# Epoch [1/10], Loss: 1.3322
# Epoch [1/10], Loss: 0.3870
# Epoch [1/10], Loss: 0.4193
# Epoch [1/10], Loss: 0.6268
# Epoch [1/10], Loss: 0.2852
# Epoch [1/10], Loss: 0.2817
# Epoch [1/10], Loss: 0.1656
# Epoch [1/10], Loss: 0.6771
# Epoch [1/10], Loss: 0.9320
# Epoch [1/10], Loss: 0.4590
# Epoch [1/10], Loss: 0.6519
# Epoch [1/10], Loss: 0.3547
# Epoch [1/10], Loss: 0.2191
# Epoch [1/10], Loss: 0.9901
# Epoch [1/10], Loss: 0.0831
# Epoch [1/10], Loss: 0.5035
# Epoch [1/10], Loss: 0.8147
# Epoch [1/10], Loss: 0.3516
# Epoch [1/10], Loss: 0.2994
# Epoch [1/10], Loss: 0.6358
# Epoch [1/10], Loss: 0.6807
# Epoch [1/10], Loss: 0.5662
# Epoch [1/10], Loss: 1.1655
# Epoch [1/10], Loss: 0.2892
# Epoch [1/10], Loss: 0.2846
# Epoch [1/10], Loss: 0.0645
# Epoch [1/10], Loss: 2.4032
# Epoch [1/10], Loss: 0.3022
# Epoch [1/10], Loss: 0.7658
# Epoch [1/10], Loss: 0.5807
# Epoch [1/10], Loss: 0.6051
# Epoch [1/10], Loss: 0.2349
# Epoch [1/10], Loss: 0.6014
# Epoch [1/10], Loss: 0.2850
# Epoch [1/10], Loss: 0.0566
# Epoch [1/10], Loss: 0.2476
# Epoch [1/10], Loss: 1.3684
# Epoch [1/10], Loss: 0.4114
# Epoch [1/10], Loss: 0.3565
# Epoch [1/10], Loss: 0.0319
# Epoch [1/10], Loss: 0.0286
# Epoch [1/10], Loss: 0.9678
# Epoch [1/10], Loss: 0.4810
# Epoch [1/10], Loss: 0.8739
# Epoch [1/10], Loss: 0.2671
# Epoch [1/10], Loss: 0.4378
# Epoch [1/10], Loss: 0.5955
# Epoch [1/10], Loss: 0.1454
# Epoch [1/10], Loss: 1.4310
# Epoch [1/10], Loss: 0.8857
# Epoch [1/10], Loss: 0.3007
# Epoch [1/10], Loss: 0.4192
# Epoch [1/10], Loss: 0.0797
# Epoch [1/10], Loss: 0.2458
# Epoch [1/10], Loss: 1.2328
# Epoch [1/10], Loss: 0.6414
# Epoch [1/10], Loss: 0.3450
# Epoch [1/10], Loss: 0.0247
# Epoch [1/10], Loss: 0.4704
# Epoch [1/10], Loss: 0.7219
# Epoch [1/10], Loss: 1.5684
# Epoch [1/10], Loss: 0.2356
# Epoch [1/10], Loss: 0.1942
# Epoch [1/10], Loss: 0.6140
# Epoch [1/10], Loss: 3.4300
# Epoch [1/10], Loss: 0.4247
# Epoch [1/10], Loss: 0.3741
# Epoch [1/10], Loss: 0.2184
# Epoch [1/10], Loss: 0.9814
# Epoch [1/10], Loss: 1.1238
# Epoch [1/10], Loss: 0.3690
# Epoch [1/10], Loss: 0.6388
# Epoch [1/10], Loss: 0.0790
# Epoch [1/10], Loss: 0.0444
# Epoch [1/10], Loss: 1.1379
# Epoch [1/10], Loss: 0.6748
# Epoch [1/10], Loss: 0.3208
# Epoch [1/10], Loss: 0.0355
# Epoch [1/10], Loss: 0.9660
# Epoch [1/10], Loss: 1.0025
# Epoch [1/10], Loss: 0.9985
# Epoch [1/10], Loss: 0.6710
# Epoch [1/10], Loss: 0.4392
# Epoch [1/10], Loss: 0.2124
# Epoch [1/10], Loss: 0.8317
# Epoch [1/10], Loss: 0.8537
# Epoch [1/10], Loss: 0.2494
# Epoch [1/10], Loss: 0.5991
# Epoch [1/10], Loss: 1.4141
# Epoch [1/10], Loss: 0.1820
# Epoch [1/10], Loss: 0.6661
# Epoch [1/10], Loss: 1.7300
# Epoch [1/10], Loss: 0.0413
# Epoch [1/10], Loss: 0.3775
# Epoch [1/10], Loss: 0.3229
# Epoch [1/10], Loss: 0.0912
# Epoch [1/10], Loss: 0.6151
# Epoch [1/10], Loss: 0.0898
# Epoch [1/10], Loss: 0.3801
# Epoch [1/10], Loss: 0.4590
# Epoch [1/10], Loss: 0.1573
# Epoch [1/10], Loss: 0.2581
# Epoch [1/10], Loss: 0.7421
# Epoch [1/10], Loss: 0.5859
# Epoch [1/10], Loss: 0.5223
# Epoch [1/10], Loss: 0.2437
# Epoch [1/10], Loss: 0.0668
# Epoch [1/10], Loss: 2.2945
# Epoch [1/10], Loss: 0.3947
# Epoch [1/10], Loss: 0.0766
# Epoch [1/10], Loss: 0.2373
# Epoch [1/10], Loss: 0.4573
# Epoch [1/10], Loss: 0.3425
# Epoch [1/10], Loss: 0.1871
# Epoch [1/10], Loss: 0.3782
# Epoch [1/10], Loss: 0.0915
# Epoch [1/10], Loss: 0.2443
# Epoch [1/10], Loss: 0.5475
# Epoch [1/10], Loss: 0.4390
# Epoch [1/10], Loss: 1.6548
# Epoch [1/10], Loss: 0.6223
# Epoch [1/10], Loss: 0.5099
# Epoch [1/10], Loss: 0.0173
# Epoch [1/10], Loss: 0.5435
# Epoch [1/10], Loss: 0.0794
# Epoch [1/10], Loss: 0.0208
# Epoch [1/10], Loss: 0.0259
# Epoch [1/10], Loss: 0.3418
# Epoch [1/10], Loss: 0.2514
# Epoch [1/10], Loss: 0.2995
# Epoch [1/10], Loss: 0.1949
# Epoch [1/10], Loss: 0.5816
# Epoch [1/10], Loss: 0.5724
# Epoch [1/10], Loss: 0.6564
# Epoch [1/10], Loss: 0.0325
# Epoch [1/10], Loss: 1.2887
# Epoch [1/10], Loss: 0.1276
# Epoch [1/10], Loss: 0.7062
# Epoch [1/10], Loss: 0.1755
# Epoch [1/10], Loss: 0.2051
# Epoch [1/10], Loss: 1.0010
# Epoch [1/10], Loss: 0.1606
# Epoch [1/10], Loss: 0.1713
# Epoch [1/10], Loss: 0.8942
# Epoch [1/10], Loss: 0.1141
# Epoch [1/10], Loss: 0.3755
# Epoch [1/10], Loss: 0.5577
# Epoch [1/10], Loss: 0.4716
# Epoch [1/10], Loss: 0.4508
# Epoch [1/10], Loss: 1.9328
# Epoch [1/10], Loss: 1.0967
# Epoch [1/10], Loss: 0.1598
# Epoch [1/10], Loss: 0.9489
# Epoch [1/10], Loss: 0.8043
# Epoch [1/10], Loss: 0.3233
# Epoch [1/10], Loss: 0.0903
# Epoch [1/10], Loss: 1.5830
# Epoch [1/10], Loss: 0.1659
# Epoch [1/10], Loss: 0.0671
# Epoch [1/10], Loss: 0.0212
# Epoch [1/10], Loss: 1.6603
# Epoch [1/10], Loss: 0.1713
# Epoch [1/10], Loss: 0.5679
# Epoch [1/10], Loss: 0.1547
# Epoch [1/10], Loss: 0.9889
# Epoch [1/10], Loss: 1.1764
# Epoch [1/10], Loss: 0.2923
# Epoch [1/10], Loss: 0.3604
# Epoch [1/10], Loss: 0.8639
# Epoch [1/10], Loss: 0.1216
# Epoch [1/10], Loss: 0.4600
# Epoch [1/10], Loss: 0.9074
# Epoch [1/10], Loss: 0.6184
# Epoch [1/10], Loss: 0.6761
# Epoch [1/10], Loss: 1.1694
# Epoch [1/10], Loss: 1.4153
# Epoch [1/10], Loss: 0.3803
# Epoch [1/10], Loss: 0.0410
# Epoch [1/10], Loss: 0.0368
# Epoch [1/10], Loss: 0.1676
# Epoch [1/10], Loss: 0.1672
# Epoch [1/10], Loss: 0.2244
# Epoch [1/10], Loss: 0.1430
# Epoch [1/10], Loss: 0.4936
# Epoch [1/10], Loss: 0.5737
# Epoch [1/10], Loss: 0.8446
# Epoch [1/10], Loss: 1.4969
# Epoch [1/10], Loss: 0.3297
# Epoch [1/10], Loss: 0.3432
# Epoch [1/10], Loss: 0.3418
# Epoch [1/10], Loss: 0.0976
# Epoch [1/10], Loss: 0.5008
# Epoch [1/10], Loss: 0.2106
# Epoch [1/10], Loss: 0.8102
# Epoch [1/10], Loss: 0.2864
# Epoch [1/10], Loss: 0.1864
# Epoch [1/10], Loss: 0.0267
# Epoch [1/10], Loss: 2.3146
# Epoch [1/10], Loss: 0.8072
# Epoch [1/10], Loss: 0.1907
# Epoch [1/10], Loss: 0.0485
# Epoch [1/10], Loss: 0.6267
# Epoch [1/10], Loss: 0.1873
# Epoch [1/10], Loss: 0.6810
# Epoch [1/10], Loss: 0.6036
# Epoch [1/10], Loss: 1.0005
# Epoch [1/10], Loss: 1.1291
# Epoch [1/10], Loss: 1.0163
# Epoch [1/10], Loss: 1.1369
# Epoch [1/10], Loss: 0.1720
# Epoch [1/10], Loss: 0.8168
# Epoch [1/10], Loss: 0.1458
# Epoch [1/10], Loss: 0.0037
# Epoch [1/10], Loss: 0.1207
# Epoch [1/10], Loss: 1.6080
# Epoch [1/10], Loss: 0.3106
# Epoch [1/10], Loss: 1.3920
# Epoch [1/10], Loss: 0.2757
# Epoch [1/10], Loss: 0.0116
# Epoch [1/10], Loss: 1.7396
# Epoch [1/10], Loss: 0.2235
# Epoch [1/10], Loss: 0.5660
# Epoch [1/10], Loss: 0.1916
# Epoch [1/10], Loss: 0.2728
# Epoch [1/10], Loss: 0.2364
# Epoch [1/10], Loss: 0.2950
# Epoch [1/10], Loss: 0.2375
# Epoch [1/10], Loss: 0.2172
# Epoch [1/10], Loss: 0.1421
# Epoch [1/10], Loss: 0.1577
# Epoch [1/10], Loss: 0.4633
# Epoch [1/10], Loss: 0.5548
# Epoch [1/10], Loss: 0.3756
# Epoch [1/10], Loss: 0.4008
# Epoch [1/10], Loss: 0.2815
# Epoch [1/10], Loss: 0.0381
# Epoch [1/10], Loss: 0.4324
# Epoch [1/10], Loss: 0.0577
# Epoch [1/10], Loss: 0.4004
# Epoch [1/10], Loss: 0.2070
# Epoch [1/10], Loss: 0.0998
# Epoch [1/10], Loss: 0.7332
# Epoch [1/10], Loss: 0.2829
# Epoch [1/10], Loss: 0.7269
# Epoch [1/10], Loss: 0.1030
# Epoch [1/10], Loss: 0.5304
# Epoch [1/10], Loss: 0.6320
# Epoch [1/10], Loss: 0.7192
# Epoch [1/10], Loss: 0.7437
# Epoch [1/10], Loss: 0.6514
# Epoch [1/10], Loss: 0.3216
# Epoch [1/10], Loss: 0.7781
# Epoch [1/10], Loss: 0.2093
# Epoch [1/10], Loss: 0.1200
# Epoch [1/10], Loss: 0.1060
# Epoch [1/10], Loss: 0.0318
# Epoch [1/10], Loss: 0.0616
# Epoch [1/10], Loss: 0.3972
# Epoch [1/10], Loss: 0.0124
# Epoch [1/10], Loss: 0.4916
# Epoch [1/10], Loss: 0.0345
# Epoch [1/10], Loss: 0.0790
# Epoch [1/10], Loss: 0.1122
# Epoch [1/10], Loss: 0.0884
# Epoch [1/10], Loss: 0.1234
# Epoch [1/10], Loss: 0.4904
# Epoch [1/10], Loss: 0.0362
# Epoch [1/10], Loss: 0.1014
# Epoch [1/10], Loss: 0.4257
# Epoch [1/10], Loss: 0.0458
# Epoch [1/10], Loss: 1.1214
# Epoch [1/10], Loss: 0.6183
# Epoch [1/10], Loss: 0.3922
# Epoch [1/10], Loss: 1.5702
# Epoch [1/10], Loss: 0.0875
# Epoch [1/10], Loss: 0.0992
# Epoch [1/10], Loss: 0.2640
# Epoch [1/10], Loss: 0.0302
# Epoch [1/10], Loss: 0.1551
# Epoch [1/10], Loss: 0.9779
# Epoch [1/10], Loss: 0.5994
# Epoch [1/10], Loss: 0.0179
# Epoch [1/10], Loss: 0.0811
# Epoch [1/10], Loss: 0.0453
# Epoch [1/10], Loss: 0.7772
# Epoch [1/10], Loss: 0.2810
# Epoch [1/10], Loss: 0.1076
# Epoch [1/10], Loss: 0.1956
# Epoch [1/10], Loss: 1.3091
# Epoch [1/10], Loss: 0.0757
# Epoch [1/10], Loss: 0.7026
# Epoch [1/10], Loss: 0.0922
# Epoch [1/10], Loss: 0.0304
# Epoch [1/10], Loss: 0.3092
# Epoch [1/10], Loss: 0.4856
# Epoch [1/10], Loss: 0.5841
# Epoch [1/10], Loss: 1.2258
# Epoch [1/10], Loss: 0.9288
# Epoch [1/10], Loss: 0.5510
# Epoch [1/10], Loss: 0.0262
# Epoch [1/10], Loss: 0.1335
# Epoch [1/10], Loss: 0.1341
# Epoch [1/10], Loss: 0.2834
# Epoch [1/10], Loss: 0.1385
# Epoch [1/10], Loss: 0.6887
# Epoch [1/10], Loss: 0.1049
# Epoch [1/10], Loss: 0.0766
# Epoch [1/10], Loss: 0.3966
# Epoch [1/10], Loss: 0.0906
# Epoch [1/10], Loss: 0.2171
# Epoch [1/10], Loss: 1.2734
# Epoch [1/10], Loss: 0.2773
# Epoch [1/10], Loss: 0.1955
# Epoch [1/10], Loss: 0.1310
# Epoch [1/10], Loss: 0.0517
# Epoch [1/10], Loss: 0.3753
# Epoch [1/10], Loss: 0.6841
# Epoch [1/10], Loss: 0.7562
# Epoch [1/10], Loss: 0.2956
# Epoch [1/10], Loss: 0.0281
# Epoch [1/10], Loss: 0.1163
# Epoch [1/10], Loss: 0.5749
# Epoch [1/10], Loss: 0.3740
# Epoch [1/10], Loss: 0.2308
# Epoch [1/10], Loss: 0.2342
# Epoch [1/10], Loss: 0.3494
# Epoch [1/10], Loss: 0.4009
# Epoch [1/10], Loss: 0.0006
# Epoch [1/10], Loss: 0.2853
# Epoch [1/10], Loss: 1.6326
# Epoch [1/10], Loss: 0.0544
# Epoch [1/10], Loss: 0.0657
# Epoch [1/10], Loss: 0.0122
# Epoch [1/10], Loss: 0.7967
# Epoch [1/10], Loss: 0.0245
# Epoch [1/10], Loss: 0.8812
# Epoch [1/10], Loss: 0.0239
# Epoch [1/10], Loss: 0.0922
# Epoch [1/10], Loss: 0.4012
# Epoch [1/10], Loss: 0.6256
# Epoch [1/10], Loss: 0.2792
# Epoch [1/10], Loss: 0.0189
# Epoch [1/10], Loss: 0.2488
# Epoch [1/10], Loss: 0.0647
# Epoch [1/10], Loss: 0.5266
# Epoch [1/10], Loss: 0.0041
# Epoch [1/10], Loss: 0.5761
# Epoch [1/10], Loss: 0.2819
# Epoch [1/10], Loss: 0.1745
# Epoch [1/10], Loss: 1.1392
# Epoch [1/10], Loss: 0.9060
# Epoch [1/10], Loss: 0.1839
# Epoch [1/10], Loss: 0.2038
# Epoch [1/10], Loss: 0.0705
# Epoch [1/10], Loss: 0.0466
# Epoch [1/10], Loss: 0.0704
# Epoch [1/10], Loss: 0.0511
# Epoch [1/10], Loss: 0.8402
# Epoch [1/10], Loss: 0.0939
# Epoch [1/10], Loss: 0.1171
# Epoch [1/10], Loss: 0.0768
# Epoch [1/10], Loss: 0.0270
# Epoch [1/10], Loss: 0.2521
# Epoch [1/10], Loss: 0.7673
# Epoch [1/10], Loss: 0.2081
# Epoch [1/10], Loss: 0.0728
# Epoch [1/10], Loss: 0.6215
# Epoch [1/10], Loss: 0.2152
# Epoch [1/10], Loss: 0.0276
# Epoch [1/10], Loss: 1.0269
# Epoch [1/10], Loss: 0.7001
# Epoch [1/10], Loss: 0.7003
# Epoch [1/10], Loss: 0.3887
# Epoch [1/10], Loss: 0.0034
# Epoch [1/10], Loss: 0.0329
# Epoch [1/10], Loss: 0.0527
# Epoch [1/10], Loss: 0.3935
# Epoch [1/10], Loss: 0.0593
# Epoch [1/10], Loss: 0.2846
# Epoch [1/10], Loss: 0.2049
# Epoch [1/10], Loss: 0.4169
# Epoch [1/10], Loss: 0.2335
# Epoch [1/10], Loss: 0.6017
# Epoch [1/10], Loss: 0.0220
# Epoch [1/10], Loss: 0.7627
# Epoch [1/10], Loss: 0.6250
# Epoch [1/10], Loss: 0.2352
# Epoch [1/10], Loss: 0.0959
# Epoch [1/10], Loss: 0.1225
# Epoch [1/10], Loss: 0.7281
# Epoch [1/10], Loss: 0.0331
# Epoch [1/10], Loss: 0.4007
# Epoch [1/10], Loss: 0.3515
# Epoch [1/10], Loss: 0.3559
# Epoch [1/10], Loss: 0.1025
# Epoch [1/10], Loss: 0.1658
# Epoch [1/10], Loss: 0.0258
# Epoch [1/10], Loss: 0.1326
# Epoch [1/10], Loss: 0.0589
# Epoch [1/10], Loss: 0.7991
# Epoch [1/10], Loss: 0.2885
# Epoch [1/10], Loss: 0.0743
# Epoch [1/10], Loss: 0.3403
# Epoch [1/10], Loss: 0.0577
# Epoch [1/10], Loss: 0.4292
# Epoch [1/10], Loss: 0.8041
# Epoch [1/10], Loss: 0.3207
# Epoch [1/10], Loss: 0.1825
# Epoch [1/10], Loss: 0.3105
# Epoch [1/10], Loss: 1.5801
# Epoch [1/10], Loss: 0.0243
# Epoch [1/10], Loss: 0.0020
# Epoch [1/10], Loss: 0.4002
# Epoch [1/10], Loss: 0.0199
# Epoch [1/10], Loss: 0.1722
# Epoch [1/10], Loss: 0.4434
# Epoch [1/10], Loss: 0.5102
# Epoch [1/10], Loss: 0.0329
# Epoch [1/10], Loss: 0.8317
# Epoch [1/10], Loss: 0.0383
# Epoch [1/10], Loss: 0.0229
# Epoch [1/10], Loss: 0.5642
# Epoch [1/10], Loss: 0.1148
# Epoch [1/10], Loss: 0.3096
# Epoch [1/10], Loss: 0.5376
# Epoch [1/10], Loss: 0.0429
# Epoch [1/10], Loss: 0.5312
# Epoch [1/10], Loss: 0.2586
# Epoch [1/10], Loss: 0.0712
# Epoch [1/10], Loss: 0.3633
# Epoch [1/10], Loss: 0.3598
# Epoch [1/10], Loss: 0.2147
# Epoch [1/10], Loss: 0.2259
# Epoch [1/10], Loss: 0.6447
# Epoch [1/10], Loss: 0.6028
# Epoch [1/10], Loss: 0.0391
# Epoch [1/10], Loss: 1.2159
# Epoch [1/10], Loss: 0.1713
# Epoch [1/10], Loss: 0.9132
# Epoch [1/10], Loss: 0.0840
# Epoch [1/10], Loss: 0.0084
# Epoch [1/10], Loss: 0.3965
# Epoch [1/10], Loss: 0.0597
# Epoch [1/10], Loss: 0.0341
# Epoch [1/10], Loss: 0.1812
# Epoch [1/10], Loss: 0.0811
# Epoch [1/10], Loss: 0.1094
# Epoch [1/10], Loss: 0.0329
# Epoch [1/10], Loss: 0.0890
# Epoch [1/10], Loss: 1.3602
# Epoch [1/10], Loss: 0.2194
# Epoch [1/10], Loss: 0.1978
# Epoch [1/10], Loss: 0.1567
# Epoch [1/10], Loss: 0.4234
# Epoch [1/10], Loss: 0.0907
# Epoch [1/10], Loss: 0.0463
# Epoch [1/10], Loss: 0.1037
# Epoch [1/10], Loss: 0.0999
# Epoch [1/10], Loss: 0.1277
# Epoch [1/10], Loss: 0.0593
# Epoch [1/10], Loss: 0.4618
# Epoch [1/10], Loss: 0.2312
# Epoch [1/10], Loss: 0.0926
# Epoch [1/10], Loss: 0.0134
# Epoch [1/10], Loss: 1.3759
# Epoch [1/10], Loss: 1.1151
# Epoch [1/10], Loss: 0.3651
# Epoch [1/10], Loss: 0.0186
# Epoch [1/10], Loss: 0.5018
# Epoch [1/10], Loss: 0.0432
# Epoch [1/10], Loss: 1.2803
# Epoch [1/10], Loss: 0.4810
# Epoch [1/10], Loss: 0.0167
# Epoch [1/10], Loss: 0.2911
# Epoch [1/10], Loss: 0.1150
# Epoch [1/10], Loss: 0.1991
# Epoch [1/10], Loss: 1.2526
# Epoch [1/10], Loss: 1.0504
# Epoch [1/10], Loss: 0.3591
# Epoch [1/10], Loss: 0.2662
# Epoch [1/10], Loss: 0.4859
# Epoch [1/10], Loss: 0.2578
# Epoch [1/10], Loss: 0.0533
# Epoch [1/10], Loss: 0.2367
# Epoch [1/10], Loss: 0.0322
# Epoch [1/10], Loss: 0.0199
# Epoch [1/10], Loss: 0.0469
# Epoch [1/10], Loss: 0.0142
# Epoch [1/10], Loss: 0.8938
# Epoch [1/10], Loss: 0.0792
# Epoch [1/10], Loss: 0.2515
# Epoch [1/10], Loss: 0.2536
# Epoch [1/10], Loss: 0.0565
# Epoch [1/10], Loss: 0.5386
# Epoch [1/10], Loss: 0.8623
# Epoch [1/10], Loss: 0.0315
# Epoch [1/10], Loss: 0.0869
# Epoch [1/10], Loss: 0.1472
# Epoch [1/10], Loss: 0.0408
# Epoch [1/10], Loss: 0.1005
# Epoch [1/10], Loss: 0.0211
# Epoch [1/10], Loss: 0.3240
# Epoch [1/10], Loss: 0.0408
# Epoch [1/10], Loss: 0.0372
# Epoch [1/10], Loss: 0.9555
# Epoch [1/10], Loss: 0.0272
# Epoch [1/10], Loss: 0.0161
# Epoch [1/10], Loss: 0.0923
# Epoch [1/10], Loss: 0.3040
# Epoch [1/10], Loss: 0.3742
# Epoch [1/10], Loss: 0.1436
# Epoch [1/10], Loss: 0.0139
# Epoch [1/10], Loss: 0.0641
# Epoch [1/10], Loss: 0.9050
# Epoch [1/10], Loss: 0.0504
# Epoch [1/10], Loss: 0.0628
# Epoch [1/10], Loss: 0.0531
# Epoch [1/10], Loss: 0.1979
# Epoch [1/10], Loss: 0.0458
# Epoch [1/10], Loss: 0.2218
# Epoch [1/10], Loss: 0.0981
# Epoch [1/10], Loss: 0.1875
# Epoch [1/10], Loss: 0.4262
# Epoch [1/10], Loss: 0.1361
# Epoch [1/10], Loss: 0.5531
# Epoch [1/10], Loss: 0.0159
# Epoch [1/10], Loss: 0.3849
# Epoch [1/10], Loss: 0.2305
# Epoch [1/10], Loss: 0.2437
# Epoch [1/10], Loss: 0.0475
# Epoch [1/10], Loss: 0.0148
# Epoch [1/10], Loss: 0.0007
# Epoch [1/10], Loss: 1.5989
# Epoch [1/10], Loss: 0.0240
# Epoch [1/10], Loss: 0.0786
# Epoch [1/10], Loss: 0.0361
# Epoch [1/10], Loss: 0.1494
# Epoch [1/10], Loss: 0.0459
# Epoch [1/10], Loss: 0.7324
# Epoch [1/10], Loss: 0.3376
# Epoch [1/10], Loss: 0.2615
# Epoch [1/10], Loss: 0.6386
# Epoch [1/10], Loss: 0.1338
# Epoch [1/10], Loss: 0.1850
# Epoch [1/10], Loss: 0.8398
# Epoch [1/10], Loss: 0.3627
# Epoch [1/10], Loss: 0.1346
# Epoch [1/10], Loss: 0.1316
# Epoch [1/10], Loss: 0.1394
# Epoch [1/10], Loss: 0.5700
# Epoch [1/10], Loss: 0.0042
# Epoch [1/10], Loss: 0.0073
# Epoch [1/10], Loss: 0.3590
# Epoch [1/10], Loss: 0.3503
# Epoch [1/10], Loss: 1.2514
# Epoch [1/10], Loss: 0.0641
# Epoch [1/10], Loss: 0.0145
# Epoch [1/10], Loss: 0.5890
# Epoch [1/10], Loss: 0.5077
# Epoch [1/10], Loss: 0.0280
# Epoch [1/10], Loss: 0.0166
# Epoch [1/10], Loss: 0.0143
# Epoch [1/10], Loss: 0.0067
# Epoch [1/10], Loss: 0.9815
# Epoch [1/10], Loss: 0.0766
# Epoch [1/10], Loss: 0.1695
# Epoch [1/10], Loss: 0.0664
# Epoch [1/10], Loss: 0.0051
# Epoch [1/10], Loss: 1.4272
# Epoch [1/10], Loss: 0.0268
# Epoch [1/10], Loss: 0.0105
# Epoch [1/10], Loss: 0.5768
# Epoch [1/10], Loss: 0.0171
# Epoch [1/10], Loss: 0.1517
# Epoch [1/10], Loss: 0.5231
# Epoch [1/10], Loss: 0.1193
# Epoch [1/10], Loss: 0.3895
# Epoch [1/10], Loss: 0.1136
# Epoch [1/10], Loss: 0.0659
# Epoch [1/10], Loss: 0.0584
# Epoch [1/10], Loss: 1.0943
# Epoch [1/10], Loss: 0.9209
# Epoch [1/10], Loss: 0.0099
# Epoch [1/10], Loss: 0.3179
# Epoch [1/10], Loss: 0.0089
# Epoch [1/10], Loss: 0.0090
# Epoch [1/10], Loss: 0.0185
# Epoch [1/10], Loss: 0.1528
# Epoch [1/10], Loss: 0.0248
# Epoch [1/10], Loss: 0.2693
# Epoch [1/10], Loss: 0.7192
# Epoch [1/10], Loss: 0.0190
# Epoch [1/10], Loss: 1.0898
# Epoch [1/10], Loss: 0.2178
# Epoch [1/10], Loss: 0.0303
# Epoch [1/10], Loss: 0.1388
# Epoch [1/10], Loss: 0.3439
# Epoch [1/10], Loss: 0.1248
# Epoch [1/10], Loss: 0.0033
# Epoch [1/10], Loss: 0.0068
# Epoch [1/10], Loss: 0.0435
# Epoch [1/10], Loss: 0.2342
# Epoch [1/10], Loss: 0.0696
# Epoch [1/10], Loss: 0.5213
# Epoch [1/10], Loss: 0.0224
# Epoch [1/10], Loss: 0.8402
# Epoch [1/10], Loss: 0.1644
# Epoch [1/10], Loss: 0.9840
# Epoch [1/10], Loss: 0.0280
# Epoch [1/10], Loss: 0.0474
# Epoch [1/10], Loss: 0.0171
# Epoch [1/10], Loss: 0.1136
# Epoch [1/10], Loss: 0.1824
# Epoch [1/10], Loss: 1.3507
# Epoch [1/10], Loss: 0.9057
# Epoch [1/10], Loss: 0.2674
# Epoch [1/10], Loss: 0.0759
# Epoch [1/10], Loss: 0.3069
# Epoch [1/10], Loss: 0.1837
# Epoch [1/10], Loss: 0.2440
# Epoch [1/10], Loss: 0.2254
# Epoch [1/10], Loss: 0.0513
# Epoch [1/10], Loss: 0.0828
# Epoch [1/10], Loss: 0.0458
# Epoch [1/10], Loss: 0.4146
# Epoch [1/10], Loss: 0.2139
# Epoch [1/10], Loss: 0.0196
# Epoch [1/10], Loss: 0.0119
# Epoch [1/10], Loss: 0.0456
# Epoch [1/10], Loss: 0.3381
# Epoch [1/10], Loss: 0.8216
# Epoch [1/10], Loss: 0.4673
# Epoch [1/10], Loss: 0.1021
# Epoch [1/10], Loss: 0.0770
# Epoch [1/10], Loss: 0.0420
# Epoch [1/10], Loss: 0.0483
# Epoch [1/10], Loss: 0.1215
# Epoch [1/10], Loss: 0.1697
# Epoch [1/10], Loss: 0.3705
# Epoch [1/10], Loss: 0.2601
# Epoch [1/10], Loss: 2.1697
# Epoch [1/10], Loss: 0.7437
# Epoch [1/10], Loss: 0.0011
# Epoch [1/10], Loss: 0.0955
# Epoch [1/10], Loss: 0.0175
# Epoch [1/10], Loss: 0.0868
# Epoch [1/10], Loss: 0.0276
# Epoch [1/10], Loss: 0.5396
# Epoch [1/10], Loss: 0.4127
# Epoch [1/10], Loss: 0.1809
# Epoch [1/10], Loss: 0.4134
# Epoch [1/10], Loss: 0.4576
# Epoch [1/10], Loss: 0.2227
# Epoch [1/10], Loss: 0.9961
# Epoch [1/10], Loss: 0.3260
# Epoch [1/10], Loss: 0.8659
# Epoch [1/10], Loss: 0.0631
# Epoch [1/10], Loss: 0.1004
# Epoch [1/10], Loss: 1.3375
# Epoch [1/10], Loss: 0.1861
# Epoch [1/10], Loss: 0.3726
# Epoch [1/10], Loss: 0.3186
# Epoch [1/10], Loss: 0.7191
# Epoch [1/10], Loss: 0.3797
# Epoch [1/10], Loss: 0.0176
# Epoch [1/10], Loss: 0.0945
# Epoch [1/10], Loss: 0.0417
# Epoch [1/10], Loss: 1.0488
# Epoch [1/10], Loss: 0.0279
# Epoch [1/10], Loss: 0.2256
# Epoch [1/10], Loss: 0.0202
# Epoch [1/10], Loss: 0.6175
# Epoch [1/10], Loss: 0.0400
# Epoch [1/10], Loss: 0.0579
# Epoch [1/10], Loss: 0.4359
# Epoch [1/10], Loss: 0.1727
# Epoch [1/10], Loss: 0.0213
# Epoch [1/10], Loss: 0.0874
# Epoch [1/10], Loss: 0.1291
# Epoch [1/10], Loss: 0.0283
# Epoch [1/10], Loss: 0.0088
# Epoch [1/10], Loss: 0.7359
# Epoch [1/10], Loss: 0.1129
# Epoch [1/10], Loss: 0.0894
# Epoch [1/10], Loss: 0.1900
# Epoch [1/10], Loss: 1.6423
# Epoch [1/10], Loss: 0.0021
# Epoch [1/10], Loss: 0.1351
# Epoch [1/10], Loss: 0.0840
# Epoch [1/10], Loss: 0.1636
# Epoch [1/10], Loss: 0.0292
# Epoch [1/10], Loss: 0.3206
# Epoch [1/10], Loss: 0.3178
# Epoch [1/10], Loss: 0.1608
# Epoch [1/10], Loss: 0.0810
# Epoch [1/10], Loss: 0.0374
# Epoch [1/10], Loss: 0.0757
# Epoch [1/10], Loss: 0.0266
# Epoch [1/10], Loss: 0.2288
# Epoch [1/10], Loss: 0.0247
# Epoch [1/10], Loss: 0.0144
# Epoch [1/10], Loss: 0.0075
# Epoch [1/10], Loss: 0.0055
# Epoch [1/10], Loss: 0.1483
# Epoch [1/10], Loss: 0.0338
# Epoch [1/10], Loss: 0.0611
# Epoch [1/10], Loss: 0.0207
# Epoch [1/10], Loss: 0.1754
# Epoch [1/10], Loss: 0.0177
# Epoch [1/10], Loss: 0.7081
# Epoch [1/10], Loss: 0.0151
# Epoch [1/10], Loss: 0.0936
# Epoch [1/10], Loss: 0.3770
# Epoch [1/10], Loss: 0.0061
# Epoch [1/10], Loss: 0.0387
# Epoch [1/10], Loss: 0.0581
# Epoch [1/10], Loss: 0.2533
# Epoch [1/10], Loss: 0.0601
# Epoch [1/10], Loss: 0.0019
# Epoch [1/10], Loss: 0.2792
# Epoch [1/10], Loss: 0.0080
# Epoch [1/10], Loss: 0.0141
# Epoch [1/10], Loss: 1.0137
# Epoch [1/10], Loss: 0.0046
# Epoch [1/10], Loss: 0.0145
# Epoch [1/10], Loss: 1.4093
# Epoch [1/10], Loss: 0.1744
# Epoch [1/10], Loss: 0.0030
# Epoch [1/10], Loss: 0.5647
# Epoch [1/10], Loss: 0.1804
# Epoch [1/10], Loss: 0.0209
# Epoch [1/10], Loss: 2.0342
# Epoch [1/10], Loss: 0.9822
# Epoch [1/10], Loss: 0.1772
# Epoch [1/10], Loss: 3.2559
# Epoch [1/10], Loss: 0.0170
# Epoch [1/10], Loss: 1.9559
# Epoch [1/10], Loss: 0.0620
# Epoch [1/10], Loss: 0.0983
# Epoch [1/10], Loss: 0.0729
# Epoch [1/10], Loss: 0.0683
# Epoch [1/10], Loss: 0.0725
# Epoch [1/10], Loss: 0.2257
# Epoch [1/10], Loss: 0.8360
# Epoch [1/10], Loss: 0.1285
# Epoch [1/10], Loss: 0.0201
# Epoch [1/10], Loss: 0.7275
# Epoch [1/10], Loss: 0.2342
# Epoch [1/10], Loss: 0.0251
# Epoch [1/10], Loss: 0.3091
# Epoch [1/10], Loss: 0.1961
# Epoch [1/10], Loss: 0.5596
# Epoch [1/10], Loss: 0.3938
# Epoch [1/10], Loss: 0.1572
# Epoch [1/10], Loss: 0.0263
# Epoch [1/10], Loss: 0.1525
# Epoch [1/10], Loss: 0.0550
# Epoch [1/10], Loss: 0.2300
# Epoch [1/10], Loss: 0.0073
# Epoch [1/10], Loss: 0.0070
# Epoch [1/10], Loss: 0.0333
# Epoch [1/10], Loss: 0.2842
# Epoch [1/10], Loss: 0.6854
# Epoch [1/10], Loss: 0.0336
# Epoch [1/10], Loss: 0.0398
# Epoch [1/10], Loss: 0.1183
# Epoch [1/10], Loss: 1.1419
# Epoch [1/10], Loss: 0.0217
# Epoch [1/10], Loss: 0.4458
# Epoch [1/10], Loss: 0.2750
# Epoch [1/10], Loss: 0.1058
# Epoch [1/10], Loss: 0.0426
# Epoch [1/10], Loss: 0.1598
# Epoch [1/10], Loss: 0.0642
# Epoch [1/10], Loss: 0.0409
# Epoch [1/10], Loss: 0.0829
# Epoch [1/10], Loss: 0.0674
# Epoch [1/10], Loss: 0.2924
# Epoch [1/10], Loss: 0.1209
# Epoch [1/10], Loss: 0.0573
# Epoch [1/10], Loss: 0.0997
# Epoch [1/10], Loss: 0.2165
# Epoch [1/10], Loss: 0.0052
# Epoch [1/10], Loss: 0.0727
# Epoch [1/10], Loss: 0.0157
# Epoch [1/10], Loss: 0.0403
# Epoch [1/10], Loss: 0.1309
# Epoch [1/10], Loss: 0.0084
# Epoch [1/10], Loss: 0.5692
# Epoch [1/10], Loss: 0.0067
# Epoch [1/10], Loss: 0.8273
# Epoch [1/10], Loss: 0.0034
# Epoch [1/10], Loss: 0.0959
# Epoch [1/10], Loss: 0.0279
# Epoch [1/10], Loss: 0.3667
# Epoch [1/10], Loss: 0.0664
# Epoch [1/10], Loss: 0.0005
# Epoch [1/10], Loss: 0.1982
# Epoch [1/10], Loss: 0.6290
# Epoch [1/10], Loss: 0.2933
# Epoch [1/10], Loss: 0.0857
# Epoch [1/10], Loss: 0.1273
# Epoch [1/10], Loss: 0.1002
# Epoch [1/10], Loss: 0.0493
# Epoch [1/10], Loss: 0.1289
# Epoch [1/10], Loss: 1.3369
# Epoch [1/10], Loss: 0.0086
# Epoch [1/10], Loss: 0.0032
# Epoch [1/10], Loss: 0.3069
# Epoch [1/10], Loss: 0.0301
# Epoch [1/10], Loss: 0.3804
# Epoch [1/10], Loss: 0.0372
# Epoch [1/10], Loss: 0.0537
# Epoch [1/10], Loss: 0.0143
# Epoch [1/10], Loss: 0.0910
# Epoch [1/10], Loss: 1.2492
# Epoch [1/10], Loss: 0.0287
# Epoch [1/10], Loss: 0.2295
# Epoch [1/10], Loss: 1.3501
# Epoch [1/10], Loss: 0.2636
# Epoch [1/10], Loss: 0.0616
# Epoch [1/10], Loss: 0.0090
# Epoch [1/10], Loss: 0.2285
# Epoch [1/10], Loss: 0.0604
# Epoch [1/10], Loss: 0.6095
# Epoch [1/10], Loss: 0.0097
# Epoch [1/10], Loss: 3.2621
# Epoch [1/10], Loss: 0.0847
# Epoch [1/10], Loss: 0.4345
# Epoch [1/10], Loss: 0.0292
# Epoch [1/10], Loss: 0.2543
# Epoch [1/10], Loss: 0.0297
# Epoch [1/10], Loss: 0.0344
# Epoch [1/10], Loss: 0.2014
# Epoch [1/10], Loss: 0.0027
# Epoch [1/10], Loss: 0.0935
# Epoch [1/10], Loss: 0.3693
# Epoch [1/10], Loss: 0.2663
# Epoch [1/10], Loss: 0.2127
# Epoch [1/10], Loss: 0.0533
# Epoch [1/10], Loss: 0.0063
# Epoch [1/10], Loss: 0.2753
# Epoch [1/10], Loss: 0.6537
# Epoch [1/10], Loss: 0.0500
# Epoch [1/10], Loss: 2.0552
# Epoch [1/10], Loss: 0.1071
# Epoch [1/10], Loss: 0.0881
# Epoch [1/10], Loss: 0.3073
# Epoch [1/10], Loss: 0.1904
# Epoch [1/10], Loss: 0.0613
# Epoch [1/10], Loss: 0.9380
# Epoch [1/10], Loss: 0.4890
# Epoch [1/10], Loss: 0.0840
# Epoch [1/10], Loss: 0.0987
# Epoch [1/10], Loss: 1.0047
# Epoch [1/10], Loss: 0.4405
# Epoch [1/10], Loss: 0.3917
# Epoch [1/10], Loss: 0.0294
# Epoch [1/10], Loss: 0.1656
# Epoch [1/10], Loss: 0.2696
# Epoch [1/10], Loss: 0.1438
# Epoch [1/10], Loss: 0.6563
# Epoch [1/10], Loss: 0.0121
# Epoch [1/10], Loss: 0.1353
# Epoch [1/10], Loss: 0.0078
# Epoch [1/10], Loss: 0.1333
# Epoch [1/10], Loss: 0.1242
# Epoch [1/10], Loss: 1.2122
# Epoch [1/10], Loss: 0.0314
# Epoch [1/10], Loss: 0.0483
# Epoch [1/10], Loss: 0.0474
# Epoch [1/10], Loss: 0.0052
# Epoch [1/10], Loss: 0.3275
# Epoch [1/10], Loss: 0.1585
# Epoch [1/10], Loss: 0.0584
# Epoch [1/10], Loss: 0.2495
# Epoch [1/10], Loss: 0.2065
# Epoch [1/10], Loss: 0.0456
# Epoch [1/10], Loss: 0.4364
# Epoch [1/10], Loss: 0.5277
# Epoch [1/10], Loss: 0.5421
# Epoch [1/10], Loss: 0.0577
# Epoch [1/10], Loss: 0.0176
# Epoch [1/10], Loss: 0.1474
# Epoch [1/10], Loss: 0.1827
# Epoch [1/10], Loss: 0.1227
# Epoch [1/10], Loss: 0.0214
# Epoch [1/10], Loss: 0.2727
# Epoch [1/10], Loss: 0.0437
# Epoch [1/10], Loss: 0.0068
# Epoch [1/10], Loss: 0.4328
# Epoch [1/10], Loss: 1.3396
# Epoch [1/10], Loss: 0.1381
# Epoch [1/10], Loss: 1.2295
# Epoch [1/10], Loss: 0.0246
# Epoch [1/10], Loss: 0.4983
# Epoch [1/10], Loss: 0.2438
# Epoch [1/10], Loss: 0.0312
# Epoch [1/10], Loss: 0.2881
# Epoch [1/10], Loss: 0.0264
# Epoch [1/10], Loss: 0.0295
# Epoch [1/10], Loss: 0.0048
# Epoch [1/10], Loss: 0.1998
# Epoch [1/10], Loss: 0.0676
# Epoch [1/10], Loss: 0.0269
# Epoch [1/10], Loss: 0.0313
# Epoch [1/10], Loss: 0.1878
# Epoch [1/10], Loss: 0.0068
# Epoch [1/10], Loss: 0.0306
# Epoch [1/10], Loss: 0.1466
# Epoch [1/10], Loss: 0.1740
# Epoch [1/10], Loss: 0.0249
# Epoch [1/10], Loss: 0.0014
# Epoch [1/10], Loss: 0.0013
# Epoch [1/10], Loss: 0.0356
# Epoch [1/10], Loss: 0.1454
# Epoch [1/10], Loss: 0.1902
# Epoch [1/10], Loss: 0.1553
# Epoch [1/10], Loss: 0.0083
# Epoch [1/10], Loss: 0.0137
# Epoch [1/10], Loss: 0.0074
# Epoch [1/10], Loss: 0.0269
# Epoch [1/10], Loss: 0.0313
# Epoch [1/10], Loss: 0.2532
# Epoch [1/10], Loss: 0.0265
# Epoch [1/10], Loss: 0.0623
# Epoch [1/10], Loss: 0.2054
# Epoch [1/10], Loss: 0.0675
# Epoch [1/10], Loss: 0.0016
# Epoch [1/10], Loss: 0.1722
# Epoch [1/10], Loss: 0.2289
# Epoch [1/10], Loss: 0.0013
# Epoch [1/10], Loss: 0.9544
# Epoch [1/10], Loss: 0.0026
# Epoch [1/10], Loss: 0.0781
# Epoch [1/10], Loss: 0.0603
# Epoch [1/10], Loss: 0.1389
# Epoch [1/10], Loss: 0.2497
# Epoch [1/10], Loss: 0.0031
# Epoch [1/10], Loss: 0.0086
# Epoch [1/10], Loss: 0.0008
# Epoch [1/10], Loss: 0.7141
# Epoch [1/10], Loss: 0.1618
# Epoch [1/10], Loss: 0.3352
# Epoch [1/10], Loss: 0.0381
# Epoch [1/10], Loss: 1.3430
# Epoch [1/10], Loss: 0.0677
# Epoch [1/10], Loss: 0.1171
# Epoch [1/10], Loss: 0.9178
# Epoch [1/10], Loss: 0.0369
# Epoch [1/10], Loss: 0.2561
# Epoch [1/10], Loss: 0.2449
# Epoch [1/10], Loss: 0.0106
# Epoch [1/10], Loss: 0.0374
# Epoch [1/10], Loss: 0.7488
# Epoch [1/10], Loss: 0.0211
# Epoch [1/10], Loss: 0.7574
# Epoch [1/10], Loss: 0.1116
# Epoch [1/10], Loss: 0.1466
# Epoch [1/10], Loss: 0.1266
# Epoch [1/10], Loss: 0.3552
# Epoch [1/10], Loss: 0.0396
# Epoch [1/10], Loss: 0.0495
# Epoch [1/10], Loss: 0.3885
# Epoch [1/10], Loss: 0.0449
# Epoch [1/10], Loss: 0.0152
# Epoch [1/10], Loss: 0.0749
# Epoch [1/10], Loss: 0.0031
# Epoch [1/10], Loss: 0.0429
# Epoch [1/10], Loss: 0.0081
# Epoch [1/10], Loss: 0.0572
# Epoch [1/10], Loss: 0.4049
# Epoch [1/10], Loss: 1.0673
# Epoch [1/10], Loss: 0.2580
# Epoch [1/10], Loss: 1.3397
# Epoch [1/10], Loss: 0.0418
# Epoch [1/10], Loss: 1.7372
# Epoch [1/10], Loss: 0.0243
# Epoch [1/10], Loss: 0.0389
# Epoch [1/10], Loss: 0.0777
# Epoch [1/10], Loss: 0.0142
# Epoch [1/10], Loss: 0.1073
# Epoch [1/10], Loss: 0.2959
# Epoch [1/10], Loss: 0.1090
# Epoch [1/10], Loss: 0.5395
# Epoch [1/10], Loss: 0.2380
# Epoch [1/10], Loss: 0.6721
# Epoch [1/10], Loss: 0.0606
# Epoch [1/10], Loss: 0.0490
# Epoch [1/10], Loss: 0.0079
# Epoch [1/10], Loss: 0.0448
# Epoch [1/10], Loss: 0.0874
# Epoch [1/10], Loss: 0.0560
# Epoch [1/10], Loss: 0.6182
# Epoch [1/10], Loss: 1.0139
# Epoch [1/10], Loss: 0.3549
# Epoch [1/10], Loss: 0.0235
# Epoch [1/10], Loss: 0.0573
# Epoch [1/10], Loss: 0.0306
# Epoch [1/10], Loss: 1.7772
# Epoch [1/10], Loss: 0.0639
# Epoch [1/10], Loss: 0.0122
# Epoch [1/10], Loss: 0.0180
# Epoch [1/10], Loss: 0.0525
# Epoch [1/10], Loss: 0.2983
# Epoch [1/10], Loss: 0.0075
# Epoch [1/10], Loss: 0.4613
# Epoch [1/10], Loss: 0.4303
# Epoch [1/10], Loss: 0.0296
# Epoch [1/10], Loss: 0.0731
# Epoch [1/10], Loss: 0.4043
# Epoch [1/10], Loss: 0.0256
# Epoch [1/10], Loss: 0.0478
# Epoch [1/10], Loss: 0.2896
# Epoch [1/10], Loss: 0.5526
# Epoch [1/10], Loss: 1.0549
# Epoch [1/10], Loss: 0.2695
# Epoch [1/10], Loss: 0.0029
# Epoch [1/10], Loss: 0.9130
# Epoch [1/10], Loss: 0.0190
# Epoch [1/10], Loss: 0.5026
# Epoch [1/10], Loss: 0.0157
# Epoch [1/10], Loss: 0.0803
# Epoch [1/10], Loss: 0.0358
# Epoch [1/10], Loss: 0.0191
# Epoch [1/10], Loss: 0.6918
# Epoch [1/10], Loss: 0.0201
# Epoch [1/10], Loss: 0.2056
# Epoch [1/10], Loss: 0.0259
# Epoch [1/10], Loss: 0.5176
# Epoch [1/10], Loss: 0.0298
# Epoch [1/10], Loss: 0.0317
# Epoch [1/10], Loss: 0.0797
# Epoch [1/10], Loss: 0.0046
# Epoch [1/10], Loss: 0.0073
# Epoch [1/10], Loss: 0.2039
# Epoch [1/10], Loss: 0.0523
# Epoch [1/10], Loss: 0.0204
# Epoch [1/10], Loss: 0.1671
# Epoch [1/10], Loss: 0.9870
# Epoch [1/10], Loss: 0.3389
# Epoch [1/10], Loss: 0.0426
# Epoch [1/10], Loss: 0.1391
# Epoch [1/10], Loss: 0.0353
# Epoch [1/10], Loss: 0.8296
# Epoch [1/10], Loss: 0.0866
# Epoch [1/10], Loss: 0.2309
# Epoch [1/10], Loss: 0.5494
# Epoch [1/10], Loss: 1.2292
# Epoch [1/10], Loss: 0.0786
# Epoch [1/10], Loss: 0.0117
# Epoch [1/10], Loss: 0.0320
# Epoch [1/10], Loss: 0.0359
# Epoch [1/10], Loss: 0.0375
# Epoch [1/10], Loss: 0.0345
# Epoch [1/10], Loss: 0.0211
# Epoch [1/10], Loss: 0.0005
# Epoch [1/10], Loss: 0.4307
# Epoch [1/10], Loss: 0.0067
# Epoch [1/10], Loss: 0.1636
# Epoch [1/10], Loss: 0.2450
# Epoch [1/10], Loss: 0.3376
# Epoch [1/10], Loss: 0.5286
# Epoch [1/10], Loss: 0.7880
# Epoch [1/10], Loss: 0.1167
# Epoch [1/10], Loss: 0.0029
# Epoch [1/10], Loss: 0.0198
# Epoch [1/10], Loss: 0.0106
# Epoch [1/10], Loss: 0.4959
# Epoch [1/10], Loss: 0.1403
# Epoch [1/10], Loss: 0.2879
# Epoch [1/10], Loss: 0.0225
# Epoch [1/10], Loss: 0.0514
# Epoch [1/10], Loss: 0.0842
# Epoch [1/10], Loss: 0.9223
# Epoch [1/10], Loss: 0.0083
# Epoch [1/10], Loss: 0.1665
# Epoch [1/10], Loss: 0.0016
# Epoch [1/10], Loss: 0.0613
# Epoch [1/10], Loss: 0.0302
# Epoch [1/10], Loss: 0.0391
# Epoch [1/10], Loss: 0.0018
# Epoch [1/10], Loss: 0.0049
# Epoch [1/10], Loss: 0.0084
# Epoch [1/10], Loss: 0.2261
# Epoch [1/10], Loss: 0.1580
# Epoch [1/10], Loss: 1.9000
# Epoch [1/10], Loss: 0.0167
# Epoch [1/10], Loss: 0.6222
# Epoch [1/10], Loss: 0.0062
# Epoch [1/10], Loss: 0.1010
# Epoch [1/10], Loss: 0.0282
# Epoch [1/10], Loss: 0.1339
# Epoch [1/10], Loss: 1.0967
# Epoch [1/10], Loss: 0.7484
# Epoch [1/10], Loss: 0.0071
# Epoch [1/10], Loss: 0.5084
# Epoch [1/10], Loss: 0.2328
# Epoch [1/10], Loss: 1.1189
# Epoch [1/10], Loss: 0.4527
# Epoch [1/10], Loss: 0.0116
# Epoch [1/10], Loss: 0.5302
# Epoch [1/10], Loss: 0.0463
# Epoch [1/10], Loss: 0.0190
# Epoch [1/10], Loss: 0.2739
# Epoch [1/10], Loss: 0.5661
# Epoch [1/10], Loss: 0.0391
# Epoch [1/10], Loss: 0.1361
# Epoch [1/10], Loss: 0.0285
# Epoch [1/10], Loss: 0.5647
# Epoch [1/10], Loss: 0.1718
# Epoch [1/10], Loss: 0.0532
# Epoch [1/10], Loss: 0.0803
# Epoch [1/10], Loss: 0.9743
# Epoch [1/10], Loss: 0.4308
# Epoch [1/10], Loss: 0.0100
# Epoch [1/10], Loss: 0.1585
# Epoch [1/10], Loss: 0.0080
# Epoch [1/10], Loss: 0.1918
# Epoch [1/10], Loss: 0.2109
# Epoch [1/10], Loss: 0.3070
# Epoch [1/10], Loss: 0.0054
# Epoch [1/10], Loss: 0.0486
# Epoch [1/10], Loss: 0.0615
# Epoch [1/10], Loss: 0.0823
# Epoch [1/10], Loss: 0.3184
# Epoch [1/10], Loss: 0.0340
# Epoch [1/10], Loss: 0.9650
# Epoch [1/10], Loss: 0.0823
# Epoch [1/10], Loss: 0.5624
# Epoch [1/10], Loss: 1.3365
# Epoch [1/10], Loss: 0.0705
# Epoch [1/10], Loss: 0.7761
# Epoch [1/10], Loss: 0.0068
# Epoch [1/10], Loss: 0.7812
# Epoch [1/10], Loss: 0.0457
# Epoch [1/10], Loss: 0.3669
# Epoch [1/10], Loss: 0.0903
# Epoch [1/10], Loss: 0.0772
# Epoch [1/10], Loss: 0.0017
# Epoch [1/10], Loss: 0.4172
# Epoch [1/10], Loss: 0.1879
# Epoch [1/10], Loss: 0.5779
# Epoch [1/10], Loss: 0.0251
# Epoch [1/10], Loss: 0.8856
# Epoch [1/10], Loss: 0.0140
# Epoch [1/10], Loss: 0.5886
# Epoch [1/10], Loss: 0.0554
# Epoch [1/10], Loss: 0.0117
# Epoch [1/10], Loss: 0.1220
# Epoch [1/10], Loss: 0.0447
# Epoch [1/10], Loss: 0.2626
# Epoch [1/10], Loss: 0.1741
# Epoch [1/10], Loss: 0.9226
# Epoch [1/10], Loss: 0.0036
# Epoch [1/10], Loss: 0.0110
# Epoch [1/10], Loss: 0.1465
# Epoch [1/10], Loss: 0.1288
# Epoch [1/10], Loss: 0.3439
# Epoch [1/10], Loss: 0.1928
# Epoch [1/10], Loss: 0.0809
# Epoch [1/10], Loss: 0.1948
# Epoch [1/10], Loss: 0.0831
# Epoch [1/10], Loss: 1.1385
# Epoch [1/10], Loss: 0.0289
# Epoch [1/10], Loss: 0.0022
# Epoch [1/10], Loss: 0.4521
# Epoch [1/10], Loss: 0.4538
# Epoch [1/10], Loss: 0.0567
# Epoch [1/10], Loss: 0.0433
# Epoch [1/10], Loss: 1.5509
# Epoch [1/10], Loss: 0.4755
# Epoch [1/10], Loss: 0.0413
# Epoch [1/10], Loss: 0.0348
# Epoch [1/10], Loss: 0.0912
# Epoch [1/10], Loss: 0.4726
# Epoch [1/10], Loss: 0.0092
# Epoch [1/10], Loss: 0.1651
# Epoch [1/10], Loss: 0.0205
# Epoch [1/10], Loss: 0.0707
# Epoch [1/10], Loss: 0.0976
# Epoch [1/10], Loss: 0.0643
# Epoch [1/10], Loss: 0.1203
# Epoch [1/10], Loss: 0.1935
# Epoch [1/10], Loss: 0.0384
# Epoch [1/10], Loss: 0.0394
# Epoch [1/10], Loss: 0.0395
# Epoch [1/10], Loss: 0.2787
# Epoch [1/10], Loss: 0.1714
# Epoch [1/10], Loss: 0.0294
# Epoch [1/10], Loss: 0.0004
# Epoch [1/10], Loss: 0.0210
# Epoch [1/10], Loss: 1.1910
# Epoch [1/10], Loss: 0.6217
# Epoch [1/10], Loss: 0.9535
# Epoch [1/10], Loss: 0.0980
# Epoch [1/10], Loss: 0.2726
# Epoch [1/10], Loss: 0.0372
# Epoch [1/10], Loss: 0.0059
# Epoch [1/10], Loss: 0.0071
# Epoch [1/10], Loss: 1.5807
# Epoch [1/10], Loss: 0.0709
# Epoch [1/10], Loss: 0.1885
# Epoch [1/10], Loss: 0.0578
# Epoch [1/10], Loss: 0.1526
# Epoch [1/10], Loss: 0.5162
# Epoch [1/10], Loss: 0.0133
# Epoch [1/10], Loss: 0.0111
# Epoch [1/10], Loss: 0.0144
# Epoch [1/10], Loss: 0.0131
# Epoch [1/10], Loss: 0.0137
# Epoch [1/10], Loss: 0.1235
# Epoch [1/10], Loss: 0.0859
# Epoch [1/10], Loss: 0.0417
# Epoch [1/10], Loss: 0.0552
# Epoch [1/10], Loss: 0.5275
# Epoch [1/10], Loss: 0.0259
# Epoch [1/10], Loss: 0.4510
# Epoch [1/10], Loss: 0.0127
# Epoch [1/10], Loss: 0.0670
# Epoch [1/10], Loss: 0.0301
# Epoch [1/10], Loss: 0.1767
# Epoch [1/10], Loss: 2.3713
# Epoch [1/10], Loss: 0.6224
# Epoch [1/10], Loss: 0.0328
# Epoch [1/10], Loss: 0.0954
# Epoch [1/10], Loss: 0.0037
# Epoch [1/10], Loss: 0.1106
# Epoch [1/10], Loss: 0.9899
# Epoch [1/10], Loss: 0.2106
# Epoch [1/10], Loss: 0.3141
# Epoch [1/10], Loss: 0.2129
# Epoch [1/10], Loss: 0.0061
# Epoch [1/10], Loss: 0.4562
# Epoch [1/10], Loss: 0.3930
# Epoch [1/10], Loss: 0.3411
# Epoch [1/10], Loss: 0.2151
# Epoch [1/10], Loss: 0.7966
# Epoch [1/10], Loss: 0.4058
# Epoch [1/10], Loss: 0.7783
# Epoch [1/10], Loss: 0.0073
# Epoch [1/10], Loss: 0.0662
# Epoch [1/10], Loss: 0.0661
# Epoch [1/10], Loss: 0.2354
# Epoch [1/10], Loss: 0.0850
# Epoch [1/10], Loss: 0.0121
# Epoch [1/10], Loss: 0.0299
# Epoch [1/10], Loss: 0.0709
# Epoch [1/10], Loss: 0.0265
# Epoch [1/10], Loss: 0.0079
# Epoch [1/10], Loss: 0.0019
# Epoch [1/10], Loss: 0.0464
# Epoch [1/10], Loss: 0.0117
# Epoch [1/10], Loss: 0.0637
# Epoch [1/10], Loss: 0.2898
# Epoch [1/10], Loss: 0.1234
# Epoch [1/10], Loss: 0.0297
# Epoch [1/10], Loss: 0.0334
# Epoch [1/10], Loss: 0.0166
# Epoch [1/10], Loss: 0.0475
# Epoch [1/10], Loss: 0.0481
# Epoch [1/10], Loss: 0.0079
# Epoch [1/10], Loss: 0.0393
# Epoch [1/10], Loss: 0.0149
# Epoch [1/10], Loss: 0.3240
# Epoch [1/10], Loss: 0.0267
# Epoch [1/10], Loss: 2.2198
# Epoch [1/10], Loss: 0.0028
# Epoch [1/10], Loss: 0.3331
# Epoch [1/10], Loss: 0.0202
# Epoch [1/10], Loss: 1.2899
# Epoch [1/10], Loss: 0.2524
# Epoch [1/10], Loss: 0.1282
# Epoch [1/10], Loss: 0.0443
# Epoch [1/10], Loss: 0.1232
# Epoch [1/10], Loss: 0.0224
# Epoch [1/10], Loss: 0.4629
# Epoch [1/10], Loss: 0.1065
# Epoch [1/10], Loss: 0.9367
# Epoch [1/10], Loss: 0.0460
# Epoch [1/10], Loss: 0.1769
# Epoch [1/10], Loss: 0.0077
# Epoch [1/10], Loss: 0.0701
# Epoch [1/10], Loss: 0.1623
# Epoch [1/10], Loss: 0.0583
# Epoch [1/10], Loss: 0.2259
# Epoch [1/10], Loss: 0.0760
# Epoch [1/10], Loss: 0.4509
# Epoch [1/10], Loss: 0.2988
# Epoch [1/10], Loss: 0.0081
# Epoch [1/10], Loss: 0.3197
# Epoch [1/10], Loss: 0.0081
# Epoch [1/10], Loss: 0.0067
# Epoch [1/10], Loss: 0.0774
# Epoch [1/10], Loss: 0.2652
# Epoch [1/10], Loss: 0.3891
# Epoch [1/10], Loss: 0.0116
# Epoch [1/10], Loss: 0.0339
# Epoch [1/10], Loss: 0.6467
# Epoch [1/10], Loss: 0.5323
# Epoch [1/10], Loss: 0.0382
# Epoch [1/10], Loss: 0.2673
# Epoch [1/10], Loss: 0.0284
# Epoch [1/10], Loss: 0.0388
# Epoch [1/10], Loss: 0.3298
# Epoch [1/10], Loss: 0.0466
# Epoch [1/10], Loss: 0.0662
# Epoch [1/10], Loss: 0.1614
# Epoch [1/10], Loss: 0.0690
# Epoch [1/10], Loss: 0.2575
# Epoch [1/10], Loss: 0.0031
# Epoch [1/10], Loss: 0.0199
# Epoch [1/10], Loss: 0.1449
# ...
# Epoch [1/10], Loss: 0.0215
# Epoch [1/10], Loss: 1.7138
# Epoch [1/10], Loss: 0.0382
# Epoch [1/10], Loss: 0.2803
# Epoch [1/10], Loss: 0.0041
# Epoch [1/10], Loss: 0.0039
# Epoch [1/10], Loss: 0.0057
# Epoch [1/10], Loss: 0.2632
# Epoch [1/10], Loss: 0.0749
# Epoch [1/10], Loss: 0.6982
# Epoch [1/10], Loss: 0.2106
# Epoch [1/10], Loss: 0.0274
# Epoch [1/10], Loss: 0.1205
# Epoch [1/10], Loss: 0.7588
# Epoch [1/10], Loss: 0.0429
# Epoch [1/10], Loss: 0.5569
# Epoch [1/10], Loss: 0.0095
# Epoch [1/10], Loss: 0.0082
# Epoch [1/10], Loss: 0.0769
# Epoch [1/10], Loss: 0.5187
# Epoch [1/10], Loss: 0.0038
# Epoch [1/10], Loss: 0.1180
# Epoch [1/10], Loss: 0.0322
# Epoch [1/10], Loss: 0.7685
# Epoch [1/10], Loss: 0.7086
# Epoch [1/10], Loss: 0.0026
# Epoch [1/10], Loss: 0.0401
# Epoch [1/10], Loss: 0.7689
# Epoch [1/10], Loss: 0.0016
# Epoch [1/10], Loss: 0.0202
# Epoch [1/10], Loss: 0.0615
# Epoch [1/10], Loss: 0.1125
# Epoch [1/10], Loss: 0.0693
# Epoch [1/10], Loss: 0.1099
# Epoch [1/10], Loss: 0.0293
# Epoch [1/10], Loss: 0.3646
# Epoch [1/10], Loss: 0.0045
# Epoch [1/10], Loss: 0.1045
# Epoch [1/10], Loss: 0.0066
# Epoch [1/10], Loss: 0.1513
# Epoch [1/10], Loss: 0.0266
# Epoch [1/10], Loss: 0.2796
# Epoch [1/10], Loss: 0.1751
# Epoch [1/10], Loss: 0.1604
# Epoch [1/10], Loss: 0.0123
# Epoch [1/10], Loss: 0.0108
# Epoch [1/10], Loss: 0.0010
# Epoch [1/10], Loss: 0.0401
# Epoch [1/10], Loss: 0.0083
# Epoch [1/10], Loss: 0.0401
# Epoch [1/10], Loss: 0.0067
# Epoch [1/10], Loss: 0.0384
# Epoch [1/10], Loss: 0.0944
# Epoch [1/10], Loss: 0.4318
# Epoch [1/10], Loss: 0.4545
# Epoch [1/10], Loss: 0.0048
# Epoch [1/10], Loss: 0.0509
# Epoch [1/10], Loss: 1.2525
# Epoch [1/10], Loss: 0.0054
# Epoch [1/10], Loss: 0.0226
# Epoch [1/10], Loss: 0.7771
# Epoch [1/10], Loss: 0.0106
# Epoch [1/10], Loss: 0.5497
# Epoch [1/10], Loss: 0.2487
# Epoch [1/10], Loss: 0.1635
# Epoch [1/10], Loss: 0.0039
# Epoch [1/10], Loss: 0.0100
# Epoch [1/10], Loss: 0.0089
# Epoch [1/10], Loss: 0.0459
# Epoch [1/10], Loss: 0.1990
# Epoch [1/10], Loss: 0.0117
# Epoch [1/10], Loss: 0.0553
# Epoch [1/10], Loss: 0.0138
# Epoch [1/10], Loss: 0.1396
# Epoch [1/10], Loss: 0.0081
# Epoch [1/10], Loss: 0.0334
# Epoch [1/10], Loss: 0.0213
# Epoch [1/10], Loss: 0.1798
# Epoch [1/10], Loss: 0.0258
# Epoch [1/10], Loss: 0.0156
# Epoch [1/10], Loss: 0.0587
# Epoch [1/10], Loss: 0.1907
# Epoch [1/10], Loss: 0.0245
# Epoch [1/10], Loss: 0.0216
# Epoch [1/10], Loss: 0.0137
# Epoch [1/10], Loss: 0.0049
# Epoch [1/10], Loss: 0.0037
# Epoch [1/10], Loss: 0.0172
# Epoch [1/10], Loss: 0.2803
# Epoch [1/10], Loss: 0.0192
# Epoch [1/10], Loss: 0.0584
# Epoch [1/10], Loss: 0.0955
# Epoch [1/10], Loss: 0.0007
# Epoch [1/10], Loss: 0.0024
# Epoch [1/10], Loss: 0.0065
# Epoch [1/10], Loss: 1.9412
# Epoch [1/10], Loss: 0.0099
# Epoch [1/10], Loss: 0.0156
# Epoch [1/10], Loss: 0.0405
# Epoch [1/10], Loss: 0.0117
# Epoch [1/10], Loss: 0.7719
# Epoch [1/10], Loss: 0.0661
# Epoch [1/10], Loss: 0.0098
# Epoch [1/10], Loss: 0.0616
# Epoch [1/10], Loss: 0.2066
# Epoch [1/10], Loss: 0.6715
# Epoch [1/10], Loss: 0.8458
# Epoch [1/10], Loss: 0.0025
# Epoch [1/10], Loss: 0.0083
# Epoch [1/10], Loss: 0.0235
# Epoch [1/10], Loss: 0.0125
# Epoch [1/10], Loss: 0.1060
# Epoch [1/10], Loss: 0.7586
# Epoch [1/10], Loss: 0.1462
# Epoch [1/10], Loss: 0.0183
# Epoch [1/10], Loss: 0.0159
# Epoch [1/10], Loss: 0.2916
# Epoch [1/10], Loss: 0.0628
# Epoch [1/10], Loss: 0.0531
# Epoch [1/10], Loss: 0.0245
# Epoch [1/10], Loss: 0.7517
# Epoch [1/10], Loss: 0.2612
# Epoch [1/10], Loss: 0.1569
# Epoch [1/10], Loss: 0.0577
# Epoch [1/10], Loss: 0.0258
# Epoch [1/10], Loss: 0.0116
# Epoch [1/10], Loss: 0.0992
# Epoch [1/10], Loss: 0.3585
# Epoch [1/10], Loss: 0.0302
# Epoch [1/10], Loss: 0.1172
# Epoch [1/10], Loss: 0.0955
# Epoch [1/10], Loss: 0.1268
# Epoch [1/10], Loss: 0.1483
# Epoch [1/10], Loss: 0.0026
# Epoch [1/10], Loss: 0.0910
# Epoch [1/10], Loss: 0.1107
# Epoch [1/10], Loss: 0.0343
# Epoch [1/10], Loss: 1.0578
# Epoch [1/10], Loss: 0.5842
# Epoch [1/10], Loss: 0.0391
# Epoch [1/10], Loss: 0.0669
# Epoch [1/10], Loss: 0.0023
# Epoch [1/10], Loss: 0.0078
# Epoch [1/10], Loss: 0.3734
# Epoch [1/10], Loss: 0.0039
# Epoch [1/10], Loss: 0.0372
# Epoch [1/10], Loss: 0.0411
# Epoch [1/10], Loss: 0.0177
# Epoch [1/10], Loss: 0.0442
# Epoch [1/10], Loss: 0.0013
# Epoch [1/10], Loss: 0.0641
# Epoch [1/10], Loss: 0.0304
# Epoch [1/10], Loss: 0.0063
# Epoch [1/10], Loss: 0.0049
# Epoch [1/10], Loss: 0.0086
# Epoch [1/10], Loss: 0.0991
# Epoch [1/10], Loss: 0.1315
# Epoch [1/10], Loss: 0.8989
# Epoch [1/10], Loss: 0.0093
# Epoch [1/10], Loss: 0.0253
# Epoch [1/10], Loss: 0.0039
# Epoch [1/10], Loss: 0.4149
# Epoch [1/10], Loss: 0.0062
# Epoch [1/10], Loss: 0.0099
# Epoch [1/10], Loss: 0.0027
# Epoch [1/10], Loss: 0.0139
# Epoch [1/10], Loss: 0.0107
# Epoch [1/10], Loss: 0.2825
# Epoch [1/10], Loss: 0.2692
# Epoch [1/10], Loss: 0.0084
# Epoch [1/10], Loss: 0.2379
# Epoch [1/10], Loss: 0.1334
# Epoch [1/10], Loss: 0.0444
# Epoch [1/10], Loss: 0.3930
# Epoch [1/10], Loss: 0.0821
# Epoch [1/10], Loss: 0.0014
# Epoch [1/10], Loss: 0.0032
# Epoch [1/10], Loss: 0.0072
# Epoch [1/10], Loss: 0.0374
# Epoch [1/10], Loss: 0.7439
# Epoch [1/10], Loss: 0.7264
# Epoch [1/10], Loss: 0.0658
# Epoch [1/10], Loss: 0.0279
# Epoch [1/10], Loss: 0.0363
# Epoch [1/10], Loss: 0.0085
# Epoch [1/10], Loss: 0.1266
# Epoch [1/10], Loss: 0.0233
# Epoch [1/10], Loss: 0.0081
# Epoch [1/10], Loss: 0.0028
# Epoch [1/10], Loss: 0.1293
# Epoch [1/10], Loss: 0.0006
# Epoch [1/10], Loss: 0.0392
# Epoch [1/10], Loss: 0.5388
# Epoch [1/10], Loss: 0.0017
# Epoch [1/10], Loss: 0.2477
# Epoch [1/10], Loss: 0.3136
# Epoch [1/10], Loss: 0.0048
# Epoch [1/10], Loss: 0.0655
# Epoch [1/10], Loss: 0.0560
# Epoch [1/10], Loss: 0.9074
# Epoch [1/10], Loss: 0.0277
# Epoch [1/10], Loss: 0.0209
# Epoch [1/10], Loss: 0.6266
# Epoch [1/10], Loss: 0.1709
# Epoch [1/10], Loss: 0.1323
# Epoch [1/10], Loss: 0.0022
# Epoch [1/10], Loss: 0.0038
# Epoch [1/10], Loss: 0.0182
# Epoch [1/10], Loss: 0.0501
# Epoch [1/10], Loss: 0.0534
# Epoch [1/10], Loss: 0.0466
# Epoch [1/10], Loss: 0.3834
# Epoch [1/10], Loss: 0.1598
# Epoch [1/10], Loss: 0.0449
# Epoch [1/10], Loss: 0.1801
# Epoch [1/10], Loss: 0.0166
# Epoch [1/10], Loss: 0.1428
# Epoch [1/10], Loss: 0.0019
# Epoch [1/10], Loss: 0.0210
# Epoch [1/10], Loss: 0.0273
# Epoch [1/10], Loss: 0.3200
# Epoch [1/10], Loss: 0.0429
# Epoch [1/10], Loss: 0.0448
# Epoch [1/10], Loss: 0.3246
# Epoch [1/10], Loss: 0.0943
# Epoch [1/10], Loss: 0.0219
# Epoch [1/10], Loss: 0.0249
# Epoch [1/10], Loss: 1.2317
# Epoch [1/10], Loss: 0.0594
# Epoch [1/10], Loss: 0.0088
# Epoch [1/10], Loss: 0.0057
# Epoch [1/10], Loss: 0.7776
# Epoch [1/10], Loss: 1.9002
# Epoch [1/10], Loss: 0.0226
# Epoch [1/10], Loss: 0.0055
# Epoch [1/10], Loss: 0.0735
# Epoch [1/10], Loss: 0.0128
# Epoch [1/10], Loss: 0.1208
# Epoch [1/10], Loss: 0.5372
# Epoch [1/10], Loss: 0.0106
# Epoch [1/10], Loss: 0.0026
# Epoch [1/10], Loss: 0.0179
# Epoch [1/10], Loss: 0.4585
# Epoch [1/10], Loss: 0.3671
# Epoch [1/10], Loss: 0.0129
# Epoch [1/10], Loss: 0.1782
# Epoch [1/10], Loss: 0.1059
# Epoch [1/10], Loss: 0.2755
# Epoch [1/10], Loss: 0.0348
# Epoch [1/10], Loss: 0.4283
# Epoch [1/10], Loss: 0.3756
# Epoch [1/10], Loss: 0.0151
# Epoch [1/10], Loss: 0.0951
# Epoch [1/10], Loss: 2.4591
# Epoch [1/10], Loss: 0.0247
# Epoch [1/10], Loss: 0.0010
# Epoch [1/10], Loss: 0.0059
# Epoch [1/10], Loss: 0.0604
# Epoch [1/10], Loss: 0.5836
# Epoch [1/10], Loss: 0.1854
# Epoch [1/10], Loss: 0.0913
# Epoch [1/10], Loss: 0.0113
# Epoch [1/10], Loss: 0.0037
# Epoch [1/10], Loss: 0.1634
# Epoch [1/10], Loss: 0.0083
# Epoch [1/10], Loss: 0.0061
# Epoch [1/10], Loss: 0.0033
# Epoch [1/10], Loss: 0.0164
# Epoch [1/10], Loss: 0.6394
# Epoch [1/10], Loss: 0.0065
# Epoch [1/10], Loss: 0.0045
# Epoch [1/10], Loss: 0.0064
# Epoch [1/10], Loss: 0.0217
# Epoch [1/10], Loss: 0.0298
# Epoch [1/10], Loss: 0.0597
# Epoch [1/10], Loss: 0.2363
# Epoch [1/10], Loss: 0.2827
# Epoch [1/10], Loss: 0.2342
# Epoch [1/10], Loss: 0.0391
# Epoch [1/10], Loss: 0.1398
# Epoch [1/10], Loss: 0.9803
# Epoch [1/10], Loss: 0.5390
# Epoch [1/10], Loss: 0.0329
# Epoch [1/10], Loss: 0.0190
# Epoch [1/10], Loss: 0.0198
# Epoch [1/10], Loss: 0.1604
# Epoch [1/10], Loss: 0.0212
# Epoch [1/10], Loss: 0.0390
# Epoch [1/10], Loss: 2.8870
# Epoch [1/10], Loss: 0.0015
# Epoch [1/10], Loss: 0.0442
# Epoch [1/10], Loss: 0.2003
# Epoch [1/10], Loss: 0.0159
# Epoch [1/10], Loss: 0.3674
# Epoch [1/10], Loss: 0.0874
# Epoch [1/10], Loss: 0.0856
# Epoch [1/10], Loss: 0.0107
# Epoch [1/10], Loss: 0.0767
# Epoch [1/10], Loss: 0.0655
# Epoch [1/10], Loss: 0.0158
# Epoch [1/10], Loss: 0.0082
# Epoch [1/10], Loss: 0.1741
# Epoch [1/10], Loss: 0.2906
# Epoch [1/10], Loss: 0.0651
# Epoch [1/10], Loss: 0.3854
# Epoch [1/10], Loss: 0.0231
# Epoch [1/10], Loss: 0.0066
# Epoch [1/10], Loss: 0.0387
# Epoch [1/10], Loss: 0.0033
# Epoch [1/10], Loss: 0.0500
# Epoch [1/10], Loss: 0.0092
# Epoch [1/10], Loss: 0.5046
# Epoch [1/10], Loss: 0.0579
# Epoch [1/10], Loss: 0.0115
# Epoch [1/10], Loss: 0.0084
# Epoch [1/10], Loss: 0.0346
# Epoch [1/10], Loss: 0.0169
# Epoch [1/10], Loss: 0.0025
# Epoch [1/10], Loss: 0.0220
# Epoch [1/10], Loss: 0.2986
# Epoch [1/10], Loss: 0.0688
# Epoch [1/10], Loss: 0.0022
# Epoch [1/10], Loss: 0.0044
# Epoch [1/10], Loss: 0.0058
# Epoch [1/10], Loss: 0.0166
# Epoch [1/10], Loss: 0.0114
# Epoch [1/10], Loss: 0.0033
# Epoch [1/10], Loss: 0.0116
# Epoch [1/10], Loss: 0.0093
# Epoch [1/10], Loss: 0.5054
# Epoch [1/10], Loss: 0.0010
# Epoch [1/10], Loss: 0.0018
# Epoch [1/10], Loss: 0.0021
# Epoch [1/10], Loss: 0.0747
# Epoch [1/10], Loss: 0.0024
# Epoch [1/10], Loss: 0.0634
# Epoch [1/10], Loss: 0.0150
# Epoch [1/10], Loss: 0.5003
# Epoch [1/10], Loss: 0.0244
# Epoch [1/10], Loss: 0.0051
# Epoch [1/10], Loss: 0.0467
# Epoch [1/10], Loss: 0.5425
# Epoch [1/10], Loss: 0.0346
# Epoch [1/10], Loss: 0.0039
# Epoch [1/10], Loss: 0.0133
# Epoch [1/10], Loss: 0.0272
# Epoch [1/10], Loss: 0.0340
# Epoch [1/10], Loss: 0.0046
# Epoch [1/10], Loss: 0.0012
# Epoch [1/10], Loss: 0.0015
# Epoch [1/10], Loss: 0.0147
# Epoch [1/10], Loss: 1.2711
# Epoch [1/10], Loss: 0.3464
# Epoch [1/10], Loss: 1.5018
# Epoch [1/10], Loss: 0.3036
# Epoch [1/10], Loss: 0.0398
# Epoch [1/10], Loss: 0.0004
# Epoch [1/10], Loss: 0.0245
# Epoch [1/10], Loss: 0.0224
# Epoch [1/10], Loss: 0.0058
# Epoch [1/10], Loss: 0.0346
# Epoch [1/10], Loss: 0.2407
# Epoch [1/10], Loss: 0.1513
# Epoch [1/10], Loss: 0.0187
# Epoch [1/10], Loss: 0.0505
# Epoch [1/10], Loss: 0.0302
# Epoch [1/10], Loss: 0.1056
# Epoch [1/10], Loss: 0.0043
# Epoch [1/10], Loss: 0.2378
# Epoch [1/10], Loss: 0.1228
# Epoch [1/10], Loss: 0.1441
# Epoch [1/10], Loss: 0.0044
# Epoch [1/10], Loss: 0.0975
# Epoch [1/10], Loss: 0.0041
# Epoch [1/10], Loss: 0.2130
# Epoch [1/10], Loss: 0.0368
# Epoch [1/10], Loss: 0.0112
# Epoch [1/10], Loss: 0.2295
# Epoch [1/10], Loss: 0.0008
# Epoch [1/10], Loss: 0.0682
# Epoch [1/10], Loss: 0.0060
# Epoch [1/10], Loss: 0.0484
# Epoch [1/10], Loss: 0.0259
# Epoch [1/10], Loss: 0.0014
# Epoch [1/10], Loss: 0.0065
# Epoch [1/10], Loss: 0.0106
# Epoch [1/10], Loss: 0.0203
# Epoch [1/10], Loss: 0.0033
# Epoch [1/10], Loss: 0.1334
# Epoch [1/10], Loss: 0.1573
# Epoch [1/10], Loss: 0.0011
# Epoch [1/10], Loss: 0.0734
# Epoch [1/10], Loss: 0.0221
# Epoch [1/10], Loss: 0.0005
# Epoch [1/10], Loss: 0.0246
# Epoch [1/10], Loss: 0.0048
# Epoch [1/10], Loss: 0.1659
# Epoch [1/10], Loss: 0.0834
# Epoch [1/10], Loss: 0.0087
# Epoch [1/10], Loss: 0.0069
# Epoch [1/10], Loss: 0.0926
# Epoch [1/10], Loss: 0.7888
# Epoch [1/10], Loss: 0.0083
# Epoch [1/10], Loss: 0.0079
# Epoch [1/10], Loss: 0.2323
# Epoch [1/10], Loss: 0.0138
# Epoch [1/10], Loss: 0.0296
# Epoch [1/10], Loss: 0.7383
# Epoch [1/10], Loss: 0.1068
# Epoch [1/10], Loss: 0.1272
# Epoch [1/10], Loss: 0.0038
# Epoch [1/10], Loss: 0.4876
# Epoch [1/10], Loss: 0.0018
# Epoch [1/10], Loss: 0.4172
# Epoch [1/10], Loss: 0.0918
# Epoch [1/10], Loss: 0.0111
# Epoch [1/10], Loss: 0.3007
# Epoch [1/10], Loss: 1.0500
# Epoch [1/10], Loss: 0.0006
# Epoch [1/10], Loss: 0.0215
# Epoch [1/10], Loss: 0.0609
# Epoch [1/10], Loss: 0.1697
# Epoch [1/10], Loss: 0.0266
# Epoch [1/10], Loss: 1.5887
# Epoch [1/10], Loss: 0.7879
# Epoch [1/10], Loss: 0.0068
# Epoch [1/10], Loss: 0.0300
# Epoch [1/10], Loss: 0.0220
# Epoch [1/10], Loss: 0.1034
# Epoch [1/10], Loss: 0.0122
# Epoch [1/10], Loss: 0.0004
# Epoch [1/10], Loss: 0.0271
# Epoch [1/10], Loss: 0.0298
# Epoch [1/10], Loss: 0.0887
# Epoch [1/10], Loss: 0.0238
# Epoch [1/10], Loss: 0.0081
# Epoch [1/10], Loss: 0.0536
# Epoch [1/10], Loss: 0.0179
# Epoch [1/10], Loss: 0.0583
# Epoch [1/10], Loss: 0.0356
# Epoch [1/10], Loss: 0.0856
# Epoch [1/10], Loss: 0.0081
# Epoch [1/10], Loss: 0.1020
# Epoch [1/10], Loss: 0.1796
# Epoch [1/10], Loss: 0.0001
# Epoch [1/10], Loss: 0.0391
# Epoch [1/10], Loss: 0.3702
# Epoch [1/10], Loss: 0.0665
# Epoch [1/10], Loss: 0.0021
# Epoch [1/10], Loss: 0.0063
# Epoch [1/10], Loss: 0.1116
# Epoch [1/10], Loss: 0.0765
# Epoch [1/10], Loss: 0.1220
# Epoch [1/10], Loss: 0.0141
# Epoch [1/10], Loss: 0.0056
# Epoch [1/10], Loss: 0.0045
# Epoch [1/10], Loss: 0.0490
# Epoch [1/10], Loss: 0.0244
# Epoch [1/10], Loss: 0.1701
# Epoch [1/10], Loss: 0.0005
# Epoch [1/10], Loss: 0.2947
# Epoch [1/10], Loss: 0.0006
# Epoch [1/10], Loss: 0.0033
# Epoch [1/10], Loss: 0.0003
# Epoch [1/10], Loss: 0.8271
# Epoch [1/10], Loss: 0.3559
# Epoch [1/10], Loss: 0.0004
# Epoch [1/10], Loss: 0.0477
# Epoch [1/10], Loss: 0.1102
# Epoch [1/10], Loss: 0.0012
# Epoch [1/10], Loss: 0.0001
# Epoch [1/10], Loss: 0.0022
# Epoch [1/10], Loss: 0.0075
# Epoch [1/10], Loss: 0.0010
# Epoch [1/10], Loss: 0.0042
# Epoch [1/10], Loss: 0.1882
# Epoch [1/10], Loss: 0.9718
# Epoch [1/10], Loss: 0.0036
# Epoch [1/10], Loss: 0.0133
# Epoch [1/10], Loss: 0.0293
# Epoch [1/10], Loss: 0.1714
# Epoch [1/10], Loss: 0.0457
# Epoch [1/10], Loss: 0.0226
# Epoch [1/10], Loss: 0.0365
# Epoch [1/10], Loss: 0.0018
# Epoch [1/10], Loss: 0.0008
# Epoch [1/10], Loss: 0.0105
# Epoch [1/10], Loss: 0.4980
# Epoch [1/10], Loss: 0.0063
# Epoch [1/10], Loss: 0.4194
# Epoch [1/10], Loss: 0.0493
# Epoch [1/10], Loss: 0.0027
# Epoch [1/10], Loss: 0.0011
# Epoch [1/10], Loss: 0.2190
# Epoch [1/10], Loss: 0.0056
# Epoch [1/10], Loss: 0.0124
# Epoch [1/10], Loss: 0.2008
# Epoch [1/10], Loss: 0.0314
# Epoch [1/10], Loss: 0.1346
# Epoch [1/10], Loss: 0.0403
# Epoch [1/10], Loss: 0.0755
# Epoch [1/10], Loss: 0.4392
# Epoch [1/10], Loss: 0.0031
# Epoch [1/10], Loss: 0.0039
# Epoch [1/10], Loss: 0.0310
# Epoch [1/10], Loss: 0.1038
# Epoch [1/10], Loss: 0.0085
# Epoch [1/10], Loss: 0.0075
# Epoch [1/10], Loss: 0.0040
# Epoch [1/10], Loss: 0.0048
# Epoch [1/10], Loss: 0.0078
# Epoch [1/10], Loss: 0.6471
# Epoch [1/10], Loss: 0.0081
# Epoch [1/10], Loss: 0.3395
# Epoch [1/10], Loss: 1.0927
# Epoch [1/10], Loss: 0.0856
# Epoch [1/10], Loss: 0.0048
# Epoch [1/10], Loss: 0.0390
# Epoch [1/10], Loss: 0.0169
# Epoch [1/10], Loss: 0.0002
# Epoch [1/10], Loss: 0.0589
# Epoch [1/10], Loss: 0.0011
# Epoch [1/10], Loss: 0.0082
# Epoch [1/10], Loss: 0.0016
# Epoch [1/10], Loss: 0.1232
# Epoch [1/10], Loss: 0.0031
# Epoch [1/10], Loss: 0.0439
# Epoch [1/10], Loss: 0.1037
# Epoch [1/10], Loss: 0.1056
# [E thread_pool.cpp:113] Exception in thread pool task: mutex lock failed: Invalid argument
# [E thread_pool.cpp:113] Exception in thread pool task: mutex lock failed: Invalid argument
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 10
#       8 output = model(xtrain)
#       9 loss = criterion(output,ytrain)
# ---> 10 loss.backward()
#      11 optmizer.step()
#      12 print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/torch/_tensor.py:488, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     478 if has_torch_function_unary(self):
#     479     return handle_torch_function(
#     480         Tensor.backward,
#     481         (self,),
#    (...)
#     486         inputs=inputs,
#     487     )
# --> 488 torch.autograd.backward(
#     489     self, gradient, retain_graph, create_graph, inputs=inputs
#     490 )
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/torch/autograd/__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
model.eval()
# Out:
# alexnet(
#   (conv1): Conv2d(3, 96, kernel_size=(11, 11), stride=(4, 4))
#   (conv2): Conv2d(96, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv3): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (relu): ReLU()
#   (fc1): Linear(in_features=9216, out_features=4096, bias=True)
#   (fc2): Linear(in_features=4096, out_features=1000, bias=True)
# )

# %%
from tqdm import tqdm

# %%
correct=0
total = 0
with torch.no_grad():
    for xtest,ytest in tqdm(test_dataloader):
        output = model(xtest)
        probs = nn.Softmax(dim=1)(output)
        correct+= (torch.max(probs, 1).indices == ytest).sum().item()
        total += ytest.size(0)
# Out:
# 100%|███████████████████████████████████████| 2500/2500 [02:02<00:00, 20.39it/s]

# %%
correct/total*100
# Out:
# 94.95

# %%
from torchmetrics.classification import Accuracy,ConfusionMatrix,F1Score

accu = Accuracy(task='multiclass',num_classes=1000)
conm = ConfusionMatrix(task='multiclass',num_classes=1000)
f1s = F1Score(task='multiclass',num_classes=1000)

with torch.no_grad():
    for xtest,ytest in tqdm(test_dataloader):
        output = model(xtest)
        probs = nn.Softmax(dim=1)(output)
        pred_label = torch.max(probs, 1).indices
        accu.update(pred_label, ytest)
        conm.update(pred_label, ytest)
        f1s.update(pred_label, ytest)
# Out:
# 100%|███████████████████████████████████████| 2500/2500 [02:07<00:00, 19.56it/s]

# %%
accu.compute()
# Out:
# tensor(0.9495)

# %%
conm.compute()[:10,:10]
# Out:
# tensor([[ 965,    3,    1,    0,    0,    0,    7,    4,    0,    0],
#         [   0, 1129,    4,    1,    1,    0,    0,    0,    0,    0],
#         [   4,    5, 1002,    3,    1,    0,    1,   15,    1,    0],
#         [   0,    0,   10,  977,    2,    2,    0,   14,    2,    3],
#         [   0,    1,    3,    0,  966,    0,    6,    1,    0,    5],
#         [   1,    1,    0,   15,    7,  845,   10,    3,    2,    8],
#         [   7,    4,    0,    0,    7,    1,  939,    0,    0,    0],
#         [   0,    5,   15,    1,    5,    0,    0,  980,    0,   22],
#         [  19,   24,   17,   22,   42,   11,   21,   18,  735,   65],
#         [   4,    8,    2,    1,   28,    1,    0,    8,    0,  957]])

# %%
f1s.compute()
# Out:
# tensor(0.9495)

# %%
# T.functional.to_pil_image(xtrain[2])
